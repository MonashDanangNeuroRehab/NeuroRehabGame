# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
angles = [-0.389165223,0.3483046,0.326858371,0.330430716,0.404935271,0.457568079,0.561625659,0.6370438,0.64649564,0.635814,0.60780704,0.5647526,0.546080649,0.523393333,0.5004597,0.480512828,0.450673968,0.439685583,0.47888115,0.516998768,0.5439265,0.5496522,0.5478694,0.5421248,0.518133,0.489389569,0.4471871,0.426125675,0.414958775,0.365840256,0.293419868,0.243089661,0.185574889,0.175829366,0.164324522,-0.150657862,-0.211217716,-0.232390046,-0.261696,-0.264669925,-0.2661444,-0.271962464,-0.2705197,-0.264669925,-0.261696,-0.2502292,-0.256408662,-0.256408662,-0.251009971,-0.233230531,0.233230531,0.236562565,0.2289973,0.231546536,0.226419389,0.213978857,0.19782351,0.202708781,0.175829366,0.153233409,0.104678325,0.10653118,0.110143431,0.104678325,0.102792077,0.121946558,0.102792077,0.0927874148,0.0862292349,0.0927874148,0.10653118,0.142652526,0.149353445,0.150657862,-0.192814514,-0.198810175,-0.205584228,-0.19782351,-0.193826661,-0.213978857,-0.236562565,-0.243089661,-0.241474435,-0.247081563,0.2579304,0.220286965,0.200768948,0.2229358,0.2102893,0.200768948,0.144017667,0.121946558,-0.09691329,-0.10653118,-0.118694067,-0.10653118,-0.100870557,-0.0862292349,-0.07661668,0.09065409,0.121946558,0.153233409,0.164324522,0.179136783,0.164324522,0.1701742,0.175829366,0.1701742,0.164324522,0.146709815,0.126668811,0.121946558,0.139882311,0.146709815,-0.155766368,-0.142652526,-0.13270402,-0.110143431,-0.100870557,-0.09691329,-0.104678325,-0.113640912,-0.149353445,-0.166689038,-0.178041145,-0.186626315,-0.195835277,-0.19782351,-0.202708781,-0.211217716,-0.213978857,-0.2289973,-0.2289973,-0.227281943,-0.227281943,-0.218503237,-0.220286965,-0.222056359,-0.234902456,-0.2502292,-0.251788318,-0.2502292,-0.242283374,-0.226419389,-0.215799987,-0.205584228,-0.195835277,-0.215799987,-0.230699912,-0.260947227,-0.302611977,-0.347742349,-0.371150255,-0.397620946,-0.392669022,-0.374822527,-0.375865161,-0.382061183,-0.391671151,-0.411644727,-0.43069306,-0.436110824,-0.4182466,-0.411644727,-0.398603916,-0.375865161,-0.3432113,-0.302611977,-0.286673665,-0.2839303,-0.286673665,-0.290066361,-0.3000144,-0.313411623,-0.325057447,-0.332202464,-0.336300284,-0.3471792,-0.354982,-0.365304977,-0.385629565,-0.380521625,-0.368504822,-0.369565278,-0.365304977,-0.3566318,-0.344349653,-0.338041276,-0.326259166,-0.317751855,-0.303902447,-0.278362483,-0.248660371,-0.236562565,-0.222056359,-0.20747906,-0.222056359,-0.226419389,-0.233230531,-0.2382111,-0.2478722,-0.252564222,-0.257170647,-0.292752236,-0.323246539,-0.334550232,-0.3522151,-0.3732531,-0.391171247,-0.394657254,-0.3936644,-0.390169531,-0.3753442,-0.360452,-0.342069179,-0.329244226,-0.318981081,-0.3146578,-0.323851317,-0.3220336,-0.327456445,-0.330430716,-0.33861962,-0.342069179,-0.349426359,-0.353877842,-0.3566318,-0.3706227,-0.372728527,-0.404935271,-0.421972722,0.5702693,0.942945838,1.68121016,2.2471602,2.9439733,3.7155726,5.48773,6.20924139,6.74401236,7.835489,8.237164,8.894923,9.742028,9.958485,10.3430347,11.1208057,12.8243685,14.6834249,16.188839,18.5030766,19.89159,22.80231,23.7438889,24.7006035,26.0523872,29.14179,31.22181,33.0363655,34.9548,37.7944374,40.51816,42.2620277,43.44695,45.5672722,46.32899,47.51289,48.05244,48.08911,47.82997,47.7600555,47.43162,47.0233269,46.796154,45.58325,44.86023,44.4131279,43.85412,43.1387444,42.7486839,42.2636948,41.79601,41.3483,40.9906845,40.5778465,39.8170547,39.5242348,38.8252068,38.3934059,36.9322968,34.6283226,32.73123,30.8193874,28.954565,27.2318974,26.05954,24.5748653,23.2607384,21.2661762,20.5091515,20.43461,19.9000912,17.2418556,15.1853943,12.513011,9.976872,8.059489,7.357141,5.86270666,5.555943,5.61667061,6.167931,6.396661,6.0826683,5.77977467,5.41403,5.008677,3.640832,2.28413367,0.733820558,-0.473539531,-2.81932,-3.57910848,-5.2999754,-6.59020138,-9.769258,-10.9610453,-12.3915491,-13.97246,-15.6228237,-17.1615162,-18.7071838,-19.8796329,-20.9373913,-22.1711845,-23.2474442,-24.644949,-26.4477386,-28.151495,-29.4255924,-30.0421715,-32.0076,-32.726593,-33.8479576,-35.1214561,-35.5881653,-36.5523529,-36.94288,-37.4566,-37.8151054,-38.1844025,-38.2872047,-38.3891029,-38.43584,-38.50571,-38.5282249,-38.52383,-38.4993973,-38.44034,-38.41938,-38.3316422,-38.02878,-37.8906822,-37.67319,-37.5142937,-37.27518,-37.09376,-36.9234924,-36.44829,-36.2605057,-35.44502,-33.92391,-32.71745,-31.0862637,-30.2237682,-28.1225986,-27.3437157,-26.017086,-24.2934074,-22.2740326,-20.8693085,-20.0828934,-17.9161472,-16.457016,-13.5243387,-8.97275,-6.649184,-3.88302445,-1.508439,0.71051836,2.66432738,3.42588425,4.74020338,4.84529066,4.951318,5.83173227,5.723205,5.740576,5.841639,5.88736248,5.90229273,6.26331472,7.119129,7.394703,8.362222,8.708699,11.9752312,13.9453773,15.4569693,17.32792,18.7237854,19.87446,21.63769,23.5604877,24.6284885,26.4480381,28.7286816,30.2053165,32.7018166,34.8805923,37.63869,38.343277,39.9731064,40.8261757,41.6843,42.3283539,42.4980545,42.6479874,42.72665,42.7389565,42.8727341,42.90198,42.8620148,42.8519135,42.7708549,42.76073,42.7009926,42.66046,42.61421,42.5881958,42.3383522,42.2701836,42.1647072,42.03394,41.99539,41.8509254,41.706028,41.5270958,41.4740753,41.3690262,41.2879677,41.24704,41.0856552,40.97544,40.70772,40.3333969,39.7582169,39.12402,37.3485527,36.40312,33.8526077,32.938282,31.842886,29.1327248,27.155838,24.1510925,23.7441788,23.5104218,22.4591045,22.0526123,21.3801632,18.1253834,16.49871,15.904458,14.4595718,13.8344269,11.99485,9.702372,8.314889,6.8788,5.86681747,5.773294,5.12992048,4.987824,4.779097,5.52343225,5.64871645,5.90806866,5.548531,4.74392128,4.33828926,3.98560762,3.691941,2.371411,1.7511127,0.909351945,-1.7869556,-2.56902671,-4.5325036,-5.07068443,-6.896826,-8.662701,-10.7113085,-12.7995281,-13.8928919,-16.0423813,-17.1682625,-19.6181164,-20.51987,-22.0885239,-23.2510357,-25.3871021,-26.704073,-27.991003,-29.2314816,-30.1122723,-30.933876,-32.6800156,-33.3455238,-35.049118,-35.74535,-36.69962,-37.2201347,-37.9068222,-39.0965,-39.540657,-40.14569,-40.3999,-40.5987625,-40.9010429,-40.9764824,-41.0825348,-41.10528,-41.1433754,-41.1938858,-41.22773,-41.2495041,-41.29013,-41.3208,-41.3327255,-41.32988,-41.30838,-41.2129478,-41.1122665,-40.9628029,-40.7519455,-40.0003128,-39.5921059,-38.8449745,-37.80474,-37.0458565,-36.0594635,-34.9529572,-34.10766,-31.8273983,-31.120285,-28.567379,-27.5499954,-25.9561977,-24.70334,-22.4642448,-20.1867256,-17.0512676,-14.3612909,-12.8096523,-8.333406,-4.82758951,-3.10318112,-2.177447,2.34660316,3.89189,4.485327,5.0932765,5.631481,5.858994,6.151699,6.218265,6.24105024,6.338865,6.864586,7.413386,8.441502,9.767628,12.1199341,14.41463,17.2849522,17.693264,19.4555912,20.0122681,22.4318619,23.6778927,24.7975578,26.44441,26.8569126,27.8306,29.1024742,30.5213661,32.2421951,32.9232864,34.8753281,36.0594177,37.19086,37.7236862,38.44367,38.9162025,41.2235146,43.69119,46.39596,48.3027763,49.38668,50.6636276,51.35082,52.20404,53.0716248,54.3275528,55.11165,55.89306,56.5608826,56.9661751,57.081768,57.3048973,57.4283752,57.50703,57.454628,57.43967,57.3868866,57.317234,57.17908,57.0958862,57.0161133,56.9889221,56.908947,56.8671532,56.58476,56.13781,55.89195,54.9896164,54.46868,54.0515137,52.4855652,51.9740868,50.79344,50.1134071,47.3555527,44.3091469,42.22578,39.9457,38.83445,36.3255272,34.10768,32.0935135,30.7663,29.5120277,28.2469845,27.3743534,25.9700146,23.9348068,22.20694,21.5900059,21.6176758,20.9557133,20.49471,18.8262539,17.5832062,16.5340767,15.0949364,14.2836237,11.9240665,10.6968756,9.46423149,8.381526,6.536061,5.596641,5.398371,4.921075,5.94741964,6.63903046,7.10453749,7.56662273,7.574218,6.85354757,5.628522,4.516139,3.86624527,2.69704,1.91172218,-1.37472773,-1.79830921,-2.349354,-3.07427979,-3.970988,-5.56147861,-6.18786049,-8.692127,-9.309431,-11.4474726,-12.9328651,-14.32636,-15.966279,-17.1464062,-17.5996819,-19.4073734,-20.4108276,-22.3026752,-23.43158,-24.9990425,-25.90037,-27.295908,-27.9625187,-29.1690617,-29.9938469,-31.1380329,-32.4283829,-33.6120224,-35.1715851,-35.67459,-37.24061,-38.10035,-38.8755074,-39.82766,-39.9659729,-40.114315,-40.1751442,-40.23946,-40.28982,-40.3257446,-40.35824,-40.40618,-40.42656,-40.44539,-40.45037,-40.4503136,-40.4369431,-40.4471245,-40.4168663,-40.35034,-40.21759,-40.1051559,-39.8239021,-39.70236,-39.2029228,-38.5078239,-36.9419022,-36.35764,-35.5578957,-35.316967,-32.3753128,-31.589653,-31.20418,-30.3696785,-28.7828064,-26.8607063,-26.1660347,-24.1746616,-23.12049,-21.154707,-20.5059147,-17.6721153,-16.83139,-13.26144,-11.5877571,-9.45525551,-7.00521564,-4.84047651,-2.40240717,-0.450673968,1.26563179,2.32060266,3.19218183,3.71341133,4.226422,4.50397825,4.75616932,4.903447,4.83772373,4.911551,5.34595442,5.65298271,6.277042,6.91077566,7.56338024,8.79280949,10.93254,12.48151,13.8779783,15.9257545,17.0241318,19.2771683,20.235487,21.7850361,23.26751,24.3656158,25.0400467,25.55891,26.0777569,26.6377354,27.2011852,28.5483341,29.0072937,31.0517,32.14196,33.96,35.43716,36.73033,38.7915764,41.1038322,42.9682922,47.57507,49.3833542,50.5949326,53.2185745,53.9670753,55.2614021,56.0097046,56.4265366,56.62594,56.7931137,57.0419655,57.228363,57.2179451,57.146328,57.00183,56.856987,56.74226,56.420826,55.96537,54.54749,53.8037033,53.313797,52.9717674,52.22357,51.5505829,51.1892548,50.4032936,49.8145561,48.87146,46.7529373,45.954174,44.385807,43.4667549,41.3322525,40.1960335,38.76563,37.9462357,36.6224022,35.918602,34.4939,32.93688,31.3957672,30.4636688,29.5488052,28.6689262,25.2067528,23.226038,21.7238445,21.4219055,21.3373489,19.8789,18.3553047,17.43961,15.1004705,14.5506678,12.1022406,11.0323,9.616644,8.180214,7.728423,6.72412062,6.325736,5.96045732,5.911352,5.872695,5.87386274,6.67326641,7.141827,7.57528,8.301205,8.204874,8.17558,7.75638437,7.444448,6.923026,6.339885,5.69842625,4.673699,4.370764,-4.59056044,-4.701447,-5.240301,-5.669496,-7.37089,-8.955764,-10.6621189,-12.3185444,-13.8675089,-15.1940613,-16.9544735,-17.58194,-18.87231,-19.88895,-20.9244862,-22.0103264,-23.0287971,-24.151535,-25.4196377,-26.5538025,-27.2262611,-28.1736279,-29.32866,-30.0171833,-30.3690434,-30.9003525,-31.1525879,-31.4365444,-31.8893242,-31.9561272,-32.01379,-32.127552,-32.21548,-32.2270622,-32.24581,-32.2593956,-32.3337,-32.3420563,-32.34799,-32.2874031,-32.26795,-32.2469,-32.1875954,-32.15647,-32.14063,-32.10969,-32.09707,-32.0877647,-32.06564,-32.00846,-31.935154,-31.8428135,-31.6864128,-31.5324631,-31.3201332,-31.2107315,-30.7610855,-30.449728,-30.17781,-29.7031689,-29.2348022,-28.3117752,-27.3107681,-26.3164387,-25.005022,-23.2819,-21.1090374,-18.7736187,-16.5590553,-13.947772,-11.6144371,-9.972495,-8.805356,-6.2462945,-5.024026,3.55545235,4.00462627,5.044885,6.76123571,7.49936152,8.139551,8.152227,7.96222734,6.60057831,5.885531,5.678408,5.690682,5.808967,5.65679455,6.30907,6.899726,8.01038,9.66363049,10.33746,11.2088327,12.6515017,14.0736818,16.0324936,16.7052631,18.7866135,19.3367767,20.374918,21.6226425,22.5719032,23.9488525,24.7329311,26.1388912,27.1031075,28.1803112,29.45465,30.4218616,32.4413528,33.0495453,35.0545769,36.5632172,39.5657234,40.66278,42.45145,43.64715,46.807045,50.086422,50.9889565,52.91268,53.7032471,54.8237572,55.0876465,55.1848,55.270237,55.326,55.3693047,55.3991623,55.4525948,55.4185143,55.5394478,55.65374,55.68887,55.6582336,55.5581741,55.3387871,55.0171928,54.4526749,54.062027,53.6474342,52.99149,52.6292076,50.9509354,48.8749962,48.10496,46.3531532,43.7637367,42.728138,40.0837975,38.36471,37.15281,34.98317,33.4033051,30.6370735,29.7587376,29.0718231,27.2902756,25.6097279,23.483387,23.34791,23.4731445,22.4883556,22.05517,21.4573727,21.0988235,18.9303246,17.45659,15.14235,13.3115025,10.4593868,9.429609,8.709059,7.56073332,6.56620359,6.28662348,6.36996746,6.883503,8.52187,9.291765,9.182497,9.046439,8.515438,7.957986,7.47336,6.51349068,5.59145641,4.757982,3.87393641,-3.75233316,-4.75563431,-6.131334,-7.937856,-10.3724575,-11.5537558,-13.2300949,-14.2852993,-16.0452976,-16.6109085,-17.7035885,-18.1565456,-19.2714863,-20.6440029,-21.7283173,-22.5275288,-23.1039162,-24.1495762,-25.131237,-25.87753,-26.9479275,-27.5854816,-28.2047081,-28.6227856,-29.2935677,-30.15725,-30.89734,-31.31579,-32.1439743,-33.0157928,-33.7278442,-34.3218155,-34.7956772,-35.248188,-35.54505,-35.76915,-36.0776138,-36.1772156,-36.3991966,-36.703846,-37.03075,-37.310463,-37.5440331,-37.8225632,-37.96455,-38.0774879,-38.2698479,-38.3608742,-38.41423,-38.5145073,-38.6374969,-38.7144661,-38.8369255,-38.863678,-38.9478645,-39.0082474,-38.9637871,-38.8559265,-38.7564468,-38.2463379,-37.4401245,-36.2678337,-35.13228,-34.6681,-31.5264282,-30.8898315,-29.7445221,-28.6941948,-27.66359,-26.5020447,-22.8858967,-21.436264,-20.69015,-17.9787312,-15.7674971,-13.2425795,-10.7527742,-9.125051,-5.570879,-4.63045454,-2.9543283,-0.186626315,0.9095671,2.65055323,4.24233246,4.779138,5.311646,5.46938,5.468735,5.48344326,5.415586,5.327485,4.661948,4.8053,5.401855,5.7689805,6.16672325,6.50559759,7.044699,8.005281,9.367644,10.6219339,12.4243221,14.4530888,17.742403,18.7565155,20.1843,21.2396069,23.1855888,25.3295364,26.3517838,28.73962,29.5140152,30.5999451,31.10864,32.4104958,34.2051,35.618824,36.791996,39.57753,40.4119263,42.71553,43.99122,46.3588448,47.5364571,48.90565,51.04288,52.96785,55.5281448,56.10422,56.5406456,56.65437,56.81035,56.8788948,56.8440475,56.73813,56.71105,56.7197,56.7099838,56.6147728,56.5416641,56.4052963,56.2077637,55.32246,54.6457367,53.9975433,51.42347,50.68444,49.5909157,48.9283867,46.582428,44.3062668,42.09667,39.98633,38.62805,35.2131844,33.63217,31.3622246,30.1510811,28.8012142,27.0157166,26.5582237,23.88786,22.9779015,21.6797256,21.6441345,21.5019054,21.2304344,21.0610142,19.4520111,18.8064022,16.788559,16.2195568,13.7138853,12.2796507,10.1020737,9.503302,9.31629,8.126612,7.65060425,7.72504473,7.745825,9.097316,9.703973,10.035738,10.1560392,10.0095415,9.441275,8.964316,7.87957954,7.293743,4.561453,-4.46979761,-4.87941647,-5.957365,-7.13113356,-8.533178,-10.451088,-11.3140039,-12.7855539,-13.3073778,-15.5617733,-16.5047455,-17.3933067,-19.04243,-20.1657333,-21.82908,-22.9736671,-23.69459,-24.8127861,-25.88709,-26.697506,-27.6220016,-28.44952,-29.2164688,-29.9044819,-30.5185757,-30.87745,-31.6241035,-32.2199745,-32.65279,-33.1654053,-33.3095779,-33.761982,-33.93518,-34.3648758,-34.4467773,-34.61135,-34.6780052,-34.74544,-34.79926,-34.82384,-34.8340569,-34.68189,-34.5832,-34.1102333,-33.6138077,-33.12376,-32.6645,-31.90025,-31.5707664,-30.68533,-29.4069214,-28.3258629,-27.38386,-26.1797,-25.3176727,-24.2369976,-23.3580761,-22.3781719,-21.6851616,-20.1168289,-19.2391872,-17.3921547,-16.06835,-14.1653919,-12.8556871,-12.0207376,-10.3023834,-9.550614,-7.44318247,-6.77343655,-4.4185853,-3.66137171,3.331195,3.74261427,4.5632987,6.44457674,6.93378448,7.53166,7.67148161,8.156538,8.251335,7.164316,6.35051537,5.7682333,5.721424,5.87309551,6.122278,6.291082,7.012268,7.784346,7.963386,8.937251,9.590668,11.7556734,12.372612,15.0203238,16.4976177,17.8721886,18.8960285,19.9079247,20.7744827,22.0625172,22.9988,24.7646313,26.3271446,27.4539928,29.2275658,30.53783,31.5816784,32.59106,33.1098976,35.3252373,36.3841553,38.817234,39.58064,40.605835,42.38189,42.9946632,44.3762321,45.44454,45.81302,46.70261,47.583828,48.0836,48.4516,48.6290474,48.5427055,48.4483757,48.38421,48.2308426,48.1281967,47.82793,47.47419,47.0682335,46.89565,46.6249237,46.3984451,45.9500427,45.15975,44.9867973,44.29423,44.1083832,43.4763031,41.6424522,40.81578,38.88967,37.14127,36.1373,34.6503754,32.90496,31.4399357,29.7936344,28.8890343,28.47132,27.2587147,24.8612938,23.4952469,22.7777824,22.5968742,22.3661232,21.1787968,19.924015,18.6317558,16.4038429,14.4494343,14.3509054,13.8980255,13.4554434,12.1827221,10.7980022,9.476042,9.339109,9.189428,9.104808,9.144476,9.209487,9.303476,9.474548,9.569696,9.750058,9.539534,9.054515,8.607565,8.131683,6.894721,6.34924936,5.631899,5.035011,4.69548464,4.22057867,-4.697987,-5.064111,-5.78933,-6.90444374,-7.35199261,-8.052642,-9.543592,-10.0106621,-11.3713217,-12.1152,-13.4397745,-14.3879642,-15.40284,-15.8759947,-17.2086868,-18.06742,-18.7270622,-20.3635082,-20.7507362,-21.0078182,-22.21563,-23.5043068,-24.3375473,-25.5082989,-26.4517021,-27.6796074,-28.9588623,-29.8442554,-30.51165,-31.01937,-31.7141571,-32.699173,-33.1166534,-33.340435,-33.78613,-34.02165,-34.06661,-34.22188,-34.2672577,-34.34985,-34.4468231,-34.5001259,-34.55441,-34.60224,-34.68319,-34.7194481,-34.79555,-34.8073921,-34.81064,-34.7504158,-34.708477,-34.4133644,-34.180336,-33.1839,-32.691246,-31.48095,-30.8866253,-29.0913429,-28.142952,-26.553833,-25.9247437,-23.355896,-22.5312462,-21.305706,-19.6550064,-17.19588,-15.8140306,-12.6604481,-11.4141979,-8.013885,-6.791452,-3.724941,-2.70559049,2.57633042,2.90777779,4.392265,5.230832,7.65283537,7.935928,8.873384,9.186134,9.383116,9.304068,8.978222,8.377964,8.22335148,7.916809,7.83902025,7.890956,8.099316,8.392975,8.494864,9.343339,9.797194,11.4408808,12.3207216,14.9703388,16.0473976,19.09166,20.4614811,21.8544426,23.3645782,24.6359787,26.33346,27.6292725,28.73165,29.956089,30.575243,32.5449371,33.9948578,34.6167259,36.8444252,37.85812,38.57944,40.79084,41.6568642,43.3928833,44.6326981,45.6486664,47.28535,48.337532,48.80451,49.5519142,49.577282,49.615242,49.62123,49.6359634,49.5427666,49.40546,49.22863,48.95609,48.38799,48.2066536,47.8171539,47.2056923,47.040226,46.5565338,45.85667,44.933876,43.1507835,42.0070724,39.9339638,39.3799057,37.8849144,37.07149,35.22014,34.7624855,31.700882,30.9299221,30.0425873,29.8242168,28.6845341,28.2221451,26.6406288,24.7626266,24.2590942,22.7378445,22.243145,20.0497074,19.4442272,17.1334858,16.35465,15.3911858,14.7551708,14.3794966,13.817564,12.4825687,11.7834492,10.6252871,10.5431643,9.99420452,9.604514,9.471395,9.584825,9.557343,9.545035,9.466226,9.483797,9.593639,9.707841,9.651397,9.465623,9.252597,8.719518,8.044959,7.358581,6.36122,5.39379549,5.15860033,5.0716114,-5.67063665,-6.152146,-6.953333,-7.69174242,-8.885,-9.293733,-10.0786047,-10.6288061,-11.74234,-12.45921,-13.8869591,-14.3817511,-15.72738,-16.3253231,-17.2930069,-18.48376,-19.8948822,-20.5380344,-21.8318176,-23.40978,-24.8531933,-25.8148232,-26.63922,-27.10627,-28.1826611,-28.3705978,-28.66311,-28.9631844,-29.0397453,-29.159874,-29.2570648,-29.2786713,-29.3039265,-29.3091583,-29.3328762,-29.3493748,-29.3749981,-29.3826542,-29.3693771,-29.361454,-29.3434772,-29.3239517,-29.3010654,-29.28303,-29.25891,-28.953558,-28.8394489,-28.2570648,-27.9527359,-26.738348,-26.2235317,-25.1886635,-24.93899,-23.02726,-21.6338921,-21.007513,-19.6588955,-19.2616844,-16.8302689,-16.1380749,-14.2956753,-13.6801653,-11.6857882,-11.0556717,-9.300117,-7.98755646,-7.13259172,6.40027666,6.092812,6.642102,7.008239,9.089494,9.531659,10.5678835,10.728054,9.818886,9.609753,8.890947,8.133518,7.9728713,7.73129272,7.3623395,7.09658051,7.289761,7.570668,7.987458,8.361822,9.846104,10.6784048,10.7865849,11.86596,12.2688875,16.2380943,16.9926453,18.1604786,20.3881741,21.137619,21.715519,23.0632133,23.7390041,25.2055969,25.597723,27.2553825,27.928915,28.2779331,28.9972649,29.2379837,30.57682,31.17977,32.42601,33.4085541,34.6425438,35.4465065,37.79731,39.0706062,40.3280754,41.0476952,42.261425,43.39532,45.8201675,46.5340538,46.9485626,47.5819969,48.0815849,48.20263,48.4697533,48.7126427,48.6980934,48.62747,48.5926971,48.34546,48.1090431,47.79957,47.6809464,47.3799248,47.169323,46.87813,46.1472664,45.8672562,45.0864563,44.9365578,43.53506,42.8987274,41.1612053,40.5320854,38.9086838,38.25584,37.3094025,37.0408821,35.0227242,34.64988,33.054245,32.7029839,31.0039845,30.48515,28.80495,28.31215,26.5570259,26.0713062,25.5703144,24.8387833,23.28253,22.1545811,19.4140434,18.458149,16.1909218,15.8592453,15.1843767,14.5491991,13.8096256,13.06994,12.9175816,11.90261,11.6713467,10.6075287,9.551293,9.178687,8.366847,7.891379,7.13393927,7.2012434,7.54145,7.597888,7.87696362,8.121392,8.083909,7.99647331,7.998731,8.223518,8.113531,8.078053,7.724537,7.60442,7.24261761,7.067524,6.705194,6.48954248,6.369291,6.335678,6.519118,-6.66515064,-7.63925743,-7.85662842,-8.3904705,-9.154204,-9.928384,-10.7865486,-13.1603928,-13.85244,-16.0467072,-16.8343143,-17.8250237,-18.5842686,-19.6106911,-20.4124928,-21.237072,-22.3513641,-23.6768284,-24.1832085,-25.98492,-26.4072018,-27.2419853,-28.6269913,-29.6021461,-30.4426,-31.0958138,-31.8315639,-32.0829926,-32.3341331,-32.56149,-32.7110558,-32.7574234,-32.7969,-32.83545,-32.91819,-32.9970474,-33.0545959,-33.1274872,-33.15155,-33.135643,-33.09049,-32.8644142,-32.75963,-32.37814,-32.0343475,-31.0662441,-30.7042618,-29.7661839,-29.1577911,-27.7813816,-26.406456,-24.9583721,-24.3094158,-22.6634312,-21.3804626,-19.23387,-17.2437325,-16.4882336,-15.2289829,-14.6392212,-13.3338661,-11.7820282,-10.4146709,-9.253595,-8.938285,8.166257,8.009792,7.61829138,7.627894,7.71314573,8.18103,8.806204,9.057638,9.701702,9.794243,9.670139,9.428129,9.151328,9.08811,8.928081,8.83513451,8.539735,8.050081,7.853805,7.509298,8.213556,8.334325,9.691463,10.2851076,11.5618353,12.11629,13.7839785,15.4575958,16.5777359,18.8363266,21.0734882,21.7206039,23.5615368,25.2044029,27.4295979,28.5107231,30.2852783,30.60999,32.4161453,33.1352959,34.8821,35.4072723,36.8840675,37.5216942,37.91042,39.8811874,40.40219,41.7235832,42.1538849,43.2171135,43.4791832,44.7630539,45.9042931,46.4650879,47.3178062,47.4720345,47.33624,47.193676,46.93346,46.9054527,46.7255745,46.5174751,46.56214,46.3794441]

# %%
timestamps = [0.0204355,0.0335630029,0.0558033027,0.0668662041,0.0900035053,0.101471804,0.1199629,0.144730508,0.1548091,0.1716776,0.187839508,0.203674912,0.220427111,0.237349108,0.2542267,0.271492124,0.288324416,0.3040623,0.320252419,0.33594802,0.352192432,0.370951831,0.39165923,0.406130016,0.4201737,0.44156462,0.454939216,0.4692287,0.4826332,0.5020983,0.5237693,0.535396934,0.556542456,0.567995846,0.584969163,0.603736937,0.622269034,0.633081,0.6511716,0.6711381,0.690107,0.7009513,0.720460057,0.738512754,0.7497575,0.7733306,0.7851963,0.8085021,0.820481956,0.832725942,0.856292069,0.86811167,0.885645866,0.9025916,0.9245751,0.933624566,0.955797553,0.9666799,0.989228547,1.00025547,1.02206576,1.03294063,1.052637,1.07031763,1.08673024,1.102731,1.11992335,1.13686061,1.153276,1.17045641,1.18786967,1.20698571,1.21931982,1.23237586,1.25103974,1.2664212,1.28648937,1.301248,1.32318211,1.336026,1.35756409,1.36911392,1.38273036,1.40438271,1.4204607,1.44155,1.45404947,1.46733963,1.48600578,1.4990195,1.524597,1.53745711,1.5547663,1.57120109,1.588196,1.605555,1.61753762,1.635595,1.65590346,1.667436,1.68601453,1.70676625,1.71830308,1.736718,1.75631726,1.77443707,1.78476989,1.80619884,1.81692588,1.83757448,1.85665381,1.86712372,1.89019513,1.90137422,1.91975045,1.93978763,1.95141983,1.97427738,1.98657942,2.00704145,2.01819658,2.03784347,2.058019,2.07301521,2.08695841,2.09989738,2.11908245,2.13281584,2.15105343,2.173781,2.18377161,2.20157051,2.22524714,2.23805737,2.24987149,2.27400541,2.28611851,2.3043406,2.321796,2.338678,2.35238242,2.370383,2.38974714,2.40799665,2.41956329,2.43735051,2.454823,2.47267938,2.48922157,2.50470829,2.52258968,2.53961229,2.55599642,2.57162476,2.58792973,2.60460663,2.621505,2.638753,2.655134,2.671952,2.68802428,2.70419478,2.72098517,2.737532,2.75569725,2.77314,2.78553486,2.80599427,2.8175416,2.83899713,2.85094213,2.871996,2.88425255,2.90333223,2.924437,2.93548465,2.95400739,2.974055,2.98550987,3.00473261,3.01958656,3.03618288,3.05382442,3.07160926,3.088636,3.104929,3.12137985,3.139591,3.15998054,3.171663,3.1870904,3.202479,3.22362328,3.23866773,3.25530672,3.27307987,3.28807569,3.304739,3.321068,3.33765817,3.35650015,3.36728072,3.3848834,3.40332675,3.422926,3.434408,3.45336986,3.470538,3.48680782,3.50279427,3.520307,3.53621984,3.55372143,3.57046652,3.58637047,3.60225916,3.62153316,3.633665,3.65253949,3.6657927,3.69347048,3.70671248,3.71878147,3.73849869,3.75751448,3.76925683,3.782627,3.80235338,3.81750321,3.84067059,3.85320544,3.87343335,3.885533,3.90645838,3.91787124,3.93516779,3.952014,3.97421813,3.98954558,4.00060463,4.022771,4.03493261,4.052244,4.069829,4.08563232,4.10659552,4.122721,4.13793755,4.15385,4.169546,4.185781,4.20224428,4.22445059,4.234661,4.25772047,4.26751757,4.292443,4.302584,4.32027626,4.338686,4.3558526,4.3738,4.390253,4.40124655,4.42467451,4.436349,4.45352125,4.47227335,4.48377228,4.50820875,4.52135372,4.53520632,4.55540943,4.56719065,4.58653831,4.60782337,4.622763,4.63530254,4.65535545,4.668357,4.68736649,4.70633173,4.72482538,4.737552,4.755218,4.77375364,4.78366375,4.806294,4.817723,4.83644629,4.853009,4.87057638,4.88854933,4.90489769,4.922378,4.93792152,4.95414829,4.970878,4.98851252,5.00387,5.020292,5.035512,5.058012,5.07008,5.086037,5.101961,5.123904,5.134322,5.15580845,5.17198038,5.188332,5.204494,5.22039366,5.23633337,5.252755,5.27519,5.284213,5.307577,5.32430172,5.34167957,5.352411,5.376768,5.3861475,5.40375042,5.41615,5.441699,5.45418167,5.47172976,5.488766,5.507304,5.522483,5.5376544,5.554086,5.57419443,5.587256,5.606613,5.618408,5.638675,5.65791,5.67119932,5.68294525,5.707331,5.720443,5.739013,5.757964,5.76918459,5.78902149,5.80241966,5.821773,5.833694,5.859201,5.871205,5.88969946,5.901179,5.921233,5.93833,5.95041037,5.970782,5.98977661,6.001267,6.02130747,6.040755,6.051875,6.069543,6.0877223,6.103368,6.1196456,6.135526,6.158339,6.16762543,6.18484449,6.20689964,6.2232523,6.240961,6.251263,6.27416325,6.2847,6.301848,6.31881475,6.34191561,6.35800552,6.3686533,6.38954353,6.401347,6.421173,6.44073343,6.4520216,6.468959,6.485735,6.50215149,6.52368927,6.53456545,6.55547857,6.56674767,6.584919,6.60588646,6.625458,6.63643551,6.6563096,6.669895,6.688877,6.701529,6.721265,6.73356676,6.75290871,6.76585054,6.791668,6.803653,6.82176971,6.839,6.85850573,6.86830473,6.88712549,6.905928,6.91765928,6.935666,6.95842266,6.96877861,6.985965,7.00225067,7.02566051,7.03479576,7.05755758,7.07293367,7.087155,7.10895538,7.1184454,7.13628531,7.158523,7.168517,7.19025373,7.206215,7.22286367,7.23935747,7.25490856,7.26694727,7.2844286,7.30630445,7.318791,7.332088,7.35786152,7.37221861,7.38636065,7.409714,7.42160749,7.433067,7.45213127,7.472095,7.48658133,7.500222,7.523744,7.534184,7.55960035,7.56869173,7.585587,7.60389233,7.62046337,7.63634062,7.657969,7.67343664,7.69241333,7.70241,7.72085142,7.73927975,7.75048065,7.77586365,7.788813,7.800589,7.81879,7.83863354,7.85048771,7.868191,7.89033365,7.900806,7.920566,7.933313,7.951384,7.971455,7.98845863,8.005498,8.023695,8.033721,8.0568285,8.067484,8.085985,8.104979,8.116662,8.135076,8.155345,8.173093,8.184132,8.209681,8.21863,8.242324,8.253956,8.269672,8.29201,8.301243,8.325616,8.33490849,8.352347,8.369927,8.387337,8.406554,8.417653,8.438582,8.450308,8.468393,8.482046,8.505992,8.519009,8.537982,8.554859,8.572786,8.584788,8.605208,8.61675549,8.635818,8.649322,8.673927,8.68633652,8.706658,8.718124,8.73191,8.757734,8.770605,8.790365,8.803434,8.816237,8.836333,8.8494215,8.870897,8.884128,8.904297,8.922091,8.938865,8.954908,8.970975,8.988628,9.003506,9.019008,9.035256,9.057187,9.073432,9.089094,9.104506,9.125385,9.135449,9.157747,9.172585,9.18860149,9.2038,9.219694,9.236191,9.259137,9.268241,9.292391,9.302942,9.320806,9.336363,9.353409,9.369401,9.38683,9.404905,9.416695,9.434957,9.452783,9.468962,9.491462,9.500559,9.52317,9.539598,9.554672,9.5710125,9.586803,9.603348,9.621699,9.640525,9.652498,9.672178,9.684919,9.70545,9.717371,9.73838,9.750102,9.77549,9.787218,9.806537,9.816901,9.842796,9.856574,9.868207,9.889386,9.899986,9.924447,9.937641,9.955785,9.972801,9.98513,10.0028534,10.0199375,10.0421686,10.0514278,10.0690718,10.0858164,10.104147,10.1205873,10.1355543,10.1568232,10.1718817,10.1894112,10.2046022,10.2208395,10.2332039,10.25756,10.2693682,10.2885761,10.3064547,10.3249,10.3354883,10.3526678,10.3686419,10.3881426,10.4056273,10.4166794,10.4412546,10.4526463,10.4688263,10.4852962,10.5064611,10.5174408,10.54183,10.5510387,10.5698843,10.5890207,10.6003542,10.6256084,10.6376715,10.6502781,10.6685257,10.6825314,10.7030182,10.7158756,10.7367449,10.7494059,10.7689152,10.7891092,10.8011284,10.8201418,10.83829,10.8572969,10.8686457,10.888154,10.9063444,10.9177027,10.9356813,10.9526529,10.9737387,10.9849825,11.002408,11.0254917,11.0349169,11.052022,11.0698175,11.0858059,11.10837,11.1176109,11.13993,11.1547461,11.1724052,11.1882572,11.2040405,11.2199287,11.2359161,11.2565765,11.2722092,11.2874632,11.3036413,11.3251791,11.33606,11.352478,11.371356,11.3882408,11.4003706,11.4250355,11.437602,11.4554262,11.4709806,11.4877024,11.5030317,11.5191441,11.5419035,11.5518179,11.5751543,11.5840769,11.6063547,11.6228514,11.6373444,11.6541138,11.6725683,11.6835289,11.7067766,11.7179871,11.74364,11.7533951,11.7750568,11.7855577,11.8081913,11.8177614,11.8351917,11.8523808,11.87036,11.886776,11.9022026,11.9241877,11.9336052,11.9549284,11.9713907,11.9865751,12.0076256,12.0185156,12.0413408,12.0519571,12.0693846,12.0865707,12.104084,12.1203289,12.1417494,12.15069,12.1731224,12.1903334,12.2001781,12.2221241,12.2389059,12.2555447,12.2717867,12.2875156,12.3034935,12.3261023,12.3356647,12.353301,12.36639,12.3883991,12.4030561,12.4191933,12.4324884,12.4555559,12.4718657,12.4867172,12.502018,12.5168409,12.536684,12.5506945,12.5718374,12.5840292,12.6045265,12.6181736,12.6387453,12.6505947,12.67116,12.6847,12.701725,12.7201176,12.7375021,12.7547121,12.7732553,12.7893848,12.804863,12.8213949,12.8394909,12.8559494,12.8715935,12.8873768,12.90785,12.9189186,12.941124,12.9563932,12.9669437,12.9883995,13.0054073,13.0205593,13.0374432,13.0531206,13.0692482,13.0856619,13.1032047,13.1190977,13.1415071,13.1512947,13.1730509,13.1890745,13.2050056,13.2207613,13.2360735,13.2537069,13.2705679,13.2857075,13.30866,13.3178387,13.3401289,13.3549709,13.3729391,13.3848276,13.4022436,13.4216385,13.4398088,13.4523449,13.4744883,13.4856758,13.5022688,13.5252943,13.5341415,13.5568676,13.5725307,13.5877905,13.6039486,13.6205444,13.635602,13.6528549,13.6729422,13.6842413,13.7068043,13.7223692,13.7343273,13.7548962,13.7668409,13.7877874,13.801321,13.8220882,13.8338938,13.8525772,13.873023,13.8850927,13.90519,13.9174509,13.9369726,13.9576435,13.9693327,13.9881506,14.0008984,14.0256376,14.0380068,14.0559568,14.0672092,14.091917,14.1050329,14.1222811,14.1402988,14.1561832,14.1723871,14.1879587,14.2043371,14.2225,14.2397652,14.2545881,14.2718258,14.2871256,14.3032093,14.325036,14.3339844,14.3565779,14.3669386,14.3891926,14.40178,14.4189768,14.4423761,14.4513626,14.4742565,14.4845276,14.50478,14.5189543,14.5417633,14.55117,14.5685434,14.5920935,14.6023064,14.6200981,14.6390066,14.6559467,14.6726885,14.6884375,14.7060232,14.7235117,14.73437,14.75225,14.76888,14.7923527,14.800992,14.8249063,14.8342314,14.8556137,14.871088,14.8863077,14.90302,14.9198923,14.9355831,14.9581308,14.9678783,14.9898634,15.0063267,15.022438,15.0384226,15.0542078,15.0707283,15.0861635,15.1074181,15.1174154,15.13525,15.1579075,15.1753769,15.186882,15.20659,15.2191668,15.2326565,15.2568979,15.2711973,15.2829,15.301569,15.3217764,15.3401423,15.3511086,15.3652573,15.3861,15.4013014,15.4151669,15.4417753,15.4548464,15.4672747,15.4911518,15.5029879,15.5214615,15.53753,15.5555992,15.5710554,15.5873461,15.604825,15.6219368,15.638855,15.6553411,15.67193,15.6892242,15.69994,15.72042,15.7376394,15.7539358,15.77003,15.7854624,15.803709,15.820364,15.8372021,15.855135,15.8720121,15.8885927,15.9050026,15.9206409,15.9384842,15.9543495,15.9705381,15.9867926,16.0077324,16.0177612,16.04005,16.0558681,16.0719128,16.0891838,16.1064358,16.1226234,16.1388512,16.15573,16.1716766,16.1883411,16.2044449,16.2210922,16.2371826,16.2536354,16.2711544,16.2880077,16.3033619,16.3242474,16.34034,16.3564453,16.3675022,16.3858147,16.403532,16.4175987,16.4387665,16.4509258,16.4714527,16.4904957,16.5016174,16.5231762,16.5357132,16.5550175,16.5738659,16.5847435,16.6041737,16.6160984,16.6398182,16.6514854,16.670763,16.6830769,16.7033539,16.7176762,16.735836,16.7551651,16.76856,16.7898922,16.8029575,16.8201,16.83282,16.85623,16.866848,16.8878918,16.90609,16.9219151,16.93794,16.953083,16.9698563,16.9859867,17.0067844,17.0228329,17.038208,17.0539436,17.07066,17.0864315,17.1033344,17.124342,17.1355362,17.1526279,17.17481,17.1844311,17.20686,17.22267,17.2374249,17.2536163,17.2752476,17.28457,17.30206,17.3196678,17.335968,17.35818,17.367878,17.3873825,17.405901,17.4169388,17.4364758,17.4533653,17.4747,17.4901886,17.5006676,17.5200577,17.5362034,17.5577221,17.56709,17.588726,17.60561,17.6212616,17.6364632,17.6580219,17.6732273,17.6886845,17.704977,17.7212067,17.73835,17.7543964,17.7706375,17.786417,17.8106575,17.8207951,17.83759,17.8544426,17.871397,17.888155,17.9048,17.9205875,17.9374638,17.9546165,17.9720383,17.9881954,18.0046329,18.0201149,18.04183,18.0512676,18.0747147,18.08438,18.1088524,18.1187153,18.141571,18.151125,18.1700478,18.1884,18.20569,18.22198,18.237133,18.253109,18.2701931,18.2857323,18.3026466,18.31924,18.34124,18.35163,18.369482,18.388586,18.4070625,18.4190464,18.4361057,18.4534245,18.4698124,18.48716,18.5023079,18.5186329,18.5411015,18.55159,18.5735683,18.5844688,18.6066971,18.6227665,18.6377125,18.6543,18.6660824,18.6875362,18.7036057,18.7192249,18.740366,18.7564316,18.7675438,18.7900772,18.80609,18.8169613,18.8373451,18.8508568,18.8697281,18.8895912,18.9008522,18.9215,18.9377346,18.9523182,18.9735661,18.9883423,19.0026569,19.0170517,19.0388527,19.0531216,19.0720959,19.0839539,19.1022949,19.1173973,19.1427727,19.1556683,19.166935,19.1849556,19.2054787,19.222496,19.2396584,19.2502213,19.273241,19.2850323,19.3021278,19.32513,19.33498,19.3531342,19.37109,19.38303,19.4092331,19.42098,19.439024,19.457222,19.4676037,19.4886284,19.5048866,19.52037,19.53611,19.5578632,19.573082,19.5891647,19.60459,19.6208744,19.6385746,19.6544971,19.6708279,19.685894,19.7075787,19.7177849,19.735714,19.7518654,19.7745323,19.7901173,19.8003731,19.8224,19.8339272,19.85471,19.8718166,19.8867359,19.9037743,19.9192657,19.9356251,19.9574547,19.9672585,19.9906826,20.0021152,20.0244846,20.03519,20.0520725,20.06922,20.0858135,20.1079884,20.1180534,20.140749,20.1504021,20.1728477,20.1835289,20.20441,20.22082,20.2364235,20.2579575,20.2732716,20.28906,20.3052673,20.3208218,20.3326721,20.3545055,20.3719521,20.3832512,20.4077187,20.42033,20.4397736,20.4515648,20.4695873,20.4860516,20.50341,20.5204048,20.5357838,20.5579147,20.5730915,20.5885639,20.6037045,20.620224,20.63562,20.6499176,20.671917,20.6864014,20.7040787,20.7213459,20.73863,20.75494,20.7674236,20.791193,20.8023376,20.821188,20.8336,20.8545818,20.8664265,20.8874588,20.9045238,20.9170475,20.942,20.9565735,20.96866,20.9820747,21.0075073,21.0207939,21.038063,21.0560532,21.0669117,21.092165,21.1098938,21.12279,21.1347923,21.1802139,21.1945858,21.21639,21.2369747,21.2532234,21.2657967,21.28443,21.2981262,21.3172379,21.328886,21.3516,21.36747,21.3808212,21.3987942,21.4119,21.4394035,21.4531555,21.46369,21.4820347,21.4987431,21.51605,21.534502,21.5523663,21.5686588,21.5857754,21.6014385,21.6136036,21.6342831,21.6512623,21.6668072,21.6877041,21.6989288,21.7193,21.7305584,21.7533665,21.764986,21.7851715,21.80095,21.8180847,21.8349781,21.8510151,21.8672123,21.8881149,21.8986721,21.918623,21.935503,21.9505329,21.9649544,21.9872665,21.99934,22.0194378,22.0368271,22.0529861,22.0695381,22.085331,22.10216,22.1172619,22.1338043,22.1506824,22.1634426,22.1854343,22.1964378,22.217495,22.23546,22.2522049,22.26809,22.2796078,22.3021545,22.313221,22.3360424,22.34753,22.3713684,22.3848457,22.3963413,22.4151211,22.4329033,22.4511986,22.4629669,22.48461,22.4960365,22.5189953,22.52997,22.5518932,22.5627174,22.5835857,22.6005611,22.6175976,22.6345253,22.6460266,22.66808,22.6866131,22.69645,22.71743,22.72912,22.751461,22.7630386,22.7856312,22.8028984,22.8199673,22.8300285,22.8483238,22.8677387,22.88506,22.9005985,22.91679,22.933094,22.94974,22.966959,22.9840183,23.00137,23.019577,23.0306454,23.05428,23.0661221,23.08852,23.10066,23.11555,23.1354542,23.14831,23.1658916,23.1841183,23.1973228,23.214695,23.2339973,23.2514248,23.2693176,23.2855015,23.30228,23.3190536,23.3296223,23.3518867,23.3638935,23.3810139,23.3993015,23.41891,23.4311447,23.4479332,23.464735,23.4813232,23.50392,23.5150528,23.5375576,23.5496559,23.5652218,23.5883465,23.5998058,23.6153221,23.6323929,23.6483612,23.6670341,23.6828537,23.69516,23.71506,23.7319164,23.7483215,23.7667961,23.7851238,23.7979565,23.8198586,23.8312283,23.8477745,23.8664,23.8834858,23.8999577,23.9167252,23.9335155,23.9505634,23.9665947,23.98203,24.0042458,24.0164032,24.0386925,24.0500622,24.0667667,24.08261,24.09998,24.1166,24.1333942,24.1514683,24.1652584,24.1817112,24.1985569,24.2169743,24.2330475,24.2496872,24.2673,24.2844353,24.301075,24.3180046,24.33353,24.3489075,24.36581,24.3785057,24.3977261,24.4179516,24.4304066,24.4476929,24.470768,24.4809723,24.5023212,24.5135269,24.5339985,24.55021,24.5686626,24.5803661,24.6019115,24.6202259,24.6316338,24.6556988,24.6685715,24.6800251,24.6977711,24.7177467,24.731451,24.7512283,24.765604,24.7827568,24.8039684,24.8196754,24.8347054,24.8470135,24.8643837,24.88753,24.9038925,24.9156761,24.9324417,24.9509468,24.9637051,24.9879169,24.9996872,25.0158348,25.0326576,25.0490761,25.0664883,25.0827637,25.1024132,25.1148014,25.1376762,25.1498,25.1656837,25.187294,25.1985073,25.2207565,25.23192,25.252697,25.2647419,25.2866173,25.298275,25.3211136,25.3340683,25.3515224,25.3634911,25.3867626,25.399353,25.4176254,25.4305744,25.454319,25.4659,25.4878578,25.499918,25.5214062,25.5323467,25.5534439,25.56517,25.5867844,25.5983562,25.6213837,25.63274,25.6547813,25.6656513,25.6867676,25.6977386,25.718914,25.7305183,25.7516747,25.7692165,25.7799034,25.80097,25.81283,25.8343334,25.8466244,25.86757,25.8792419,25.9017277,25.9136734,25.935791,25.946619,25.96837,25.9792385,26.001009,26.01836,26.0346413,26.0525036,26.0695286,26.085741,26.10258,26.1181431,26.1360073,26.14679,26.1680336,26.1863174,26.196434,26.2168427,26.2350445,26.24755,26.2711468,26.2837639,26.299427,26.3152275,26.3326721,26.3485,26.3665428,26.3792248,26.4056225,26.4185638,26.4314747,26.4486027,26.46545,26.48321,26.5006027,26.5157051,26.5318928,26.5554523,26.56665,26.58223,26.60611,26.6180267,26.63444,26.6519337,26.6637211,26.6870461,26.6981525,26.7217255,26.7330017,26.7479935,26.7658443,26.787611,26.7981987,26.8201389,26.8320713,26.8540535,26.8653049,26.88853,26.9005032,26.9170418,26.93434,26.9458981,26.9686642,26.9811668,27.0022621,27.0132732,27.0346069,27.0459251,27.0665264,27.0829525,27.0984287,27.1156063,27.1380978,27.1497936,27.16718,27.1791153,27.2024879,27.2156887,27.2330227,27.2493973,27.2660122,27.2820511,27.3048115,27.3161316,27.3319817,27.3481522,27.3720474,27.3853054,27.3961716,27.417305,27.4309826,27.4479427,27.46353,27.48649,27.50223,27.5151863,27.5346832,27.54848,27.5657444,27.57906,27.6061764,27.6205978,27.6349983,27.6499958,27.6685467,27.6831284,27.7015362,27.714922,27.7343349,27.7480087,27.764864,27.7838383,27.8037453,27.8160343,27.832489,27.8509731,27.868351,27.8869171,27.9036312,27.9137363,27.93689,27.9486313,27.96505,27.9883,27.9998474,28.0148964,28.0366344,28.04839,28.068327,28.0794754,28.1006966,28.1185379,28.1358242,28.1518917,28.1684971,28.1793842,28.2032623,28.21606,28.2321835,28.2486267,28.2648582,28.2866249,28.2981377,28.3201542,28.332428,28.3553944,28.3666229,28.3867531,28.3978863,28.4157219,28.4342632,28.44845,28.4691029,28.4809761,28.5021229,28.5135212,28.5358944,28.54727,28.5687618,28.58031,28.6007938,28.6183815,28.63488,28.65111,28.66458,28.68337,28.6993923,28.719759,28.7325115,28.75368,28.76561,28.7825241,28.7997341,28.8155785,28.8385468,28.851635,28.8681927,28.8864441,28.9016,28.9126511,28.9331169,28.95036,28.962183,28.9841423,29.0019665,29.0129375,29.0341721,29.0463486,29.0718021,29.0850868,29.0965176,29.1210175,29.1342735,29.1458035,29.164856,29.1824341,29.2049026,29.21616,29.2366467,29.2518215,29.2642155,29.2846146,29.2993126,29.318924,29.3335323,29.350338,29.3629932,29.3833637,29.3975639,29.4211636,29.4366474,29.4511738,29.4660339,29.4850845,29.4976215,29.5233383,29.5356255,29.5501518,29.5623016,29.5860577,29.6015263,29.6155567,29.6361332,29.650486,29.6682949,29.6820641,29.6992626,29.7155,29.73763,29.74826,29.76536,29.78292,29.7986317,29.8211327,29.8319016,29.8532162,29.8644657,29.8842487,29.89607,29.9184971,29.9299145,29.95261,29.9646339,29.9860363,29.9978676,30.0198059,30.0314255,30.0547714,30.0657673,30.0877972,30.098772,30.1192131,30.1301842,30.1513176,30.1633339,30.1865063,30.1982479,30.2188988,30.2302341,30.25144,30.2627659,30.2854519,30.296814,30.3181629,30.33543,30.3510513,30.3692856,30.3826942,30.4009037,30.4145088,30.4316063,30.4518738,30.46457,30.486475,30.4979935,30.5185432,30.53017,30.5521564,30.5638142,30.584137,30.60345,30.6132832,30.6342773,30.6467686,30.6672611,30.6841564,30.6960354,30.7187462,30.73059,30.75343,30.7645931,30.7884026,30.8013763,30.8174229,30.8338184,30.8549423,30.8657856,30.88791,30.8995113,30.9150658,30.9328823,30.9469242,30.964819,30.987627,30.9990616,31.0212212,31.0337029,31.0502968,31.0669689,31.08407,31.102026,31.1183147,31.1345234,31.1518955,31.1628761,31.1851673,31.2013187,31.21245,31.23366,31.24966,31.2662182,31.28222,31.3054581,31.3183231,31.3347416,31.3514462,31.3703156,31.3832951,31.3994942,31.4123573,31.4380875,31.4530468,31.4651127,31.4860249,31.4978447,31.5198879,31.531641,31.5531139,31.5658073,31.58683,31.5982571,31.6213589,31.63264,31.65425,31.6663952,31.6823139,31.6995583,31.7190762,31.7321587,31.7482262,31.7615719,31.7813377,31.8010368,31.8136711,31.83083,31.8464851,31.8671436,31.8838081,31.9005222,31.9179478,31.932066,31.95358,31.9654846,31.9821911,32.0034027,32.0155029,32.031517,32.05365,32.065403,32.0814857,32.0989723,32.11588,32.13155,32.1542625,32.16595,32.1862564,32.19922,32.21611,32.2321548,32.24935,32.2669,32.286,32.2972832,32.3190041,32.33137,32.35247,32.36544,32.3816566,32.4005,32.412796,32.43162,32.4503021,32.4624252,32.4809875,32.4990768,32.5170135,32.529,32.55181,32.5636978,32.5869141,32.5982933,32.6198425,32.6318626,32.65334,32.66773,32.6795425,32.70272,32.716568,32.7372437,32.7480736,32.7702751,32.7832527,32.79878,32.8177567,32.8313828,32.85102,32.86542,32.8853569,32.90155,32.9207077,32.93321,32.95099,32.9680748,32.9803925,33.0054131]

# %%
test1AngularVelocitiesPadded = np.pad(test1AngularVelocities, (0, int(2**(np.ceil(math.log(np.shape(test1AngularVelocities)[0],2))+4)-np.shape(test1AngularVelocities)[0])))

# %%
plt.plot(timestamps, angles)
plt.title('Raw Angles')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
plt.plot(timestamps[0:500], angles[0:500])

# %%
def moving_average_angles(angles: np.ndarray, moving_average_window: int) -> np.ndarray:
    """
    Calculates the moving average of the given array of angles.

    Args:
    angles (np.ndarray): An array of angles in radians.
    moving_average_window (int): The size of the moving average window.

    Returns:
    np.ndarray: An array of the moving average of the input angles.
    """
    return np.convolve(angles, np.ones(moving_average_window) / moving_average_window, mode='valid')

# %%
min_angles = [-0.421972722,-38.5282249,-41.3327255,-40.45037,-32.34799,-39.0082474,-34.8340569,-34.81064,-29.3826542,10.6784048,6.335678,-33.15155,8.213556]
min_tstmps = [3.85320544,5.93833,9.003506,12.1903334,15.4151669,18.8895912,21.8672123,25.1656837,28.1518917,28.76561,30.8338184,31.4978447,32.0989723]
max_angles = [-0.2382111,48.08911,42.90198,57.50703,57.228363,55.68887,56.8788948,48.6290474,49.6359634,10.728054,48.7126427,6.519118,9.794243]
max_tstmps =[3.33765817,4.48377228,7.206215,10.3881426,13.6528549,17.038208,20.1835289,23.2855015,26.46545,28.76561,29.6361332,30.8338184,32.0989723]

# %%
plt.plot(timestamps, angles)
plt.plot(min_tstmps, min_angles, 'go')

plt.plot(max_tstmps, max_angles, 'ro')
plt.legend(['angles', 'min angles', 'max angles'])
plt.title('Max and Min Angles Achieved')

# %%
smoothed_angles = moving_average_angles(angles, 6)
plt.plot(timestamps[2:-3], smoothed_angles)
plt.title('Smoothed Angles')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
# Convert angles to angular velocities
def calculate_angular_velocities(angles: np.ndarray, timestamps: np.ndarray) -> np.ndarray:
    """
    Calculates the angular velocities based on the given angles and timestamps.

    Args:
    angles (np.ndarray): An array of angles in radians.
    timestamps (np.ndarray): An array of timestamps in seconds.

    Returns:
    np.ndarray: An array of angular velocities in radians per second.
    """
    time_diff = np.diff(timestamps)
    angle_diff = np.diff(angles)
    angular_velocities = angle_diff / time_diff
    return angular_velocities

# %%
ang_vel = calculate_angular_velocities(smoothed_angles, timestamps[2:-3])

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()

# Plot the smoothed angles on the left-hand side y-axis
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Smoothed Angles (deg)', color='tab:blue')
ax1.plot(timestamps[2:-4], smoothed_angles[0:-1], color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for the angular velocity
ax2 = ax1.twinx()
ax2.set_ylabel('Angular Velocity (deg/s)', color='tab:orange')  
ax2.plot(timestamps[2:-4], ang_vel, color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title('Angular Velocities (Smoothed Angles)')
plt.show()

# %%
# Pad and Calculate fourier coeffs + angles
angles_padded = np.pad(angles, (0, int(2**(np.ceil(math.log(len(angles),2))+4)-len(angles))))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
angles = [-0.222056359,-0.2229358,-0.258687884,-0.280463368,-0.292083085,-0.285305262,-0.2478722,-0.213978857,-0.204630241,-0.181308225,-0.183453962,-0.190774083,-0.19782351,-0.19782351,-0.198810175,-0.183453962,-0.163129419,-0.141274214,-0.121946558,-0.104678325,-0.09065409,-0.06852804,-0.04423466,0.03426402,0.06255726,0.09487279,0.104678325,0.128204256,0.145369962,0.160712555,0.193826661,0.230699912,0.223811775,0.183453962,0.154505074,0.121946558,0.121946558,0.131221235,0.125114545,0.128204256,0.110143431,0.07912937,0.0593470261,0.0523391552,0.04423466,-0.03426402,-0.04423466,-0.04423466,-0.0523391552,-0.06255726,-0.08156469,-0.100870557,-0.08156469,-0.07401875,-0.0593470261,-0.0523391552,-0.0523391552,-0.04423466,0.0279764552,0.0593470261,0.07401875,0.110143431,0.148037523,0.145369962,0.148037523,0.157017514,0.157017514,0.157017514,0.154505074,0.157017514,0.165511,0.176938713,0.176938713,0.175829366,0.150657862,0.135620937,0.131221235,0.117033929,0.113640912,0.100870557,0.08156469,0.07401875,0.0523391552,0.0593470261,0.0593470261,0.0593470261,0.0593470261,0.06255726,-0.07912937,-0.09487279,-0.09691329,-0.09487279,-0.08156469,-0.06852804,-0.06255726,-0.06255726,-0.08156469,-0.08156469,-0.08156469,-0.06852804,-0.06852804,-0.07401875,-0.07912937,-0.06852804,-0.07912937,-0.0862292349,-0.09487279,-0.100870557,-0.1203313,-0.117033929,-0.113640912,-0.104678325,-0.09691329,-0.08156469,-0.06255726,-0.04423466,-0.04423466,0.03426402,0.0523391552,0.0523391552,0.06255726,0.07401875,0.06852804,0.0593470261,0.03426402,0.03426402,0.0,0.0279764552,0.0,-0.03426402,-0.0523391552,-0.07401875,-0.07912937,-0.09691329,-0.100870557,-0.108352363,-0.113640912,-0.110143431,-0.110143431,-0.108352363,-0.09691329,-0.08156469,-0.07912937,-0.06255726,-0.04423466,-0.03426402,0.0,-0.0279764552,-0.0279764552,0.0279764552,0.03426402,0.0279764552,0.03426402,0.04423466,0.0523391552,0.0523391552,0.04423466,0.04423466,0.07401875,0.09065409,0.128204256,0.150657862,0.145369962,0.157017514,0.176938713,0.198810175,0.226419389,0.239848316,0.230699912,0.242283374,0.2601963,0.2839303,0.298051357,0.351659149,0.3716771,0.399094522,0.42104426,0.435212553,0.465622276,0.478063256,0.492180437,0.488589257,0.48132652,0.4751895,0.457568079,0.44936958,0.427501023,0.3566318,0.318981081,0.2579304,0.205584228,0.03426402,-0.0279764552,-1.43463242,-4.74425173,-6.47308445,-8.85499,-10.3118505,-11.9619408,-14.0531063,-15.1696367,-16.4238815,-17.73485,-19.2988682,-21.08584,-22.26502,-23.4173775,-24.8006172,-25.767971,-26.9792614,-28.11465,-29.9741459,-31.9061165,-32.46571,-33.332592,-34.29834,-34.95967,-35.53551,-36.0132446,-37.30411,-38.007885,-38.42713,-38.83003,-38.99994,-39.21206,-39.5013351,-39.58268,-39.6853828,-39.7278442,-39.78496,-39.7875137,-39.7656326,-39.7635155,-39.76742,-39.77361,-39.760273,-39.73764,-39.725975,-39.70499,-39.69143,-39.6675758,-39.6619225,-39.6647263,-39.6717224,-39.6846733,-39.6805344,-39.6700974,-39.6580162,-39.6473122,-39.64021,-39.63349,-39.6157875,-39.5939865,-39.5658379,-39.54362,-39.50681,-39.4403763,-39.3156471,-38.9197044,-38.207634,-37.58421,-36.8696022,-35.54968,-34.5727577,-33.5660057,-32.4194,-29.639698,-27.7675381,-25.6054688,-23.8958874,-22.0632172,-19.5169964,-16.4326,-13.9040947,-11.6726122,-9.95105648,-8.376183,-7.187991,6.56912947,6.623682,7.20753431,8.155358,9.206477,10.376174,11.2097454,12.074192,12.7145281,13.0964622,13.6728573,14.3978558,15.2834139,16.0763931,16.78047,19.3338146,20.4653015,21.4718742,22.315506,23.452549,24.8401,25.811348,27.1681671,28.5038548,30.0381069,31.616106,32.8996048,34.3613739,35.523674,37.24743,38.2694855,39.5417,40.4683533,41.3746872,42.5087738,43.6302032,44.79762,46.3883,47.4508972,47.8731232,49.1811142,50.1766129,50.9476051,51.64569,52.4338722,53.1727371,53.5451,53.8581238,54.17073,54.43802,54.7154541,54.94499,55.0582924,55.19081,55.25467,55.30069,55.3325424,55.3567543,55.36753,55.37787,55.3976555,55.4162827,55.425724,55.4809456,55.48481,55.5318031,55.5693054,55.6114349,55.683857,55.7667351,55.8285065,55.83563,55.8963776,55.9211,55.96944,55.9771767,55.99254,56.031765,55.9942551,55.9636765,55.920105,55.8955841,55.8826637,55.9066048,55.97715,56.0878677,56.0897179,55.89837,55.7205925,55.5680771,55.34312,55.1563568,54.8011551,53.94242,53.55553,53.09452,51.8933754,50.76061,47.3132172,45.16843,42.81702,39.5869255,37.2544823,34.6718521,32.7148476,30.7212524,29.3472328,27.5994911,26.5133629,23.2112255,22.2168045,21.5053711,20.5626755,20.0333233,18.6108265,17.5258331,16.7618046,16.1487617,14.9729424,14.3335905,13.7911434,13.3912888,12.7803211,11.8652468,11.29986,10.4527636,9.67455,8.925857,7.98559,7.13671637,6.417807,5.86721849,5.788314,-5.883765,-6.03523636,-6.78125,-7.7046175,-8.617302,-9.719358,-10.7834826,-11.7055664,-12.589716,-13.6411076,-15.0785885,-16.6077652,-18.2579956,-20.4284363,-21.64493,-23.004797,-24.25931,-25.79232,-26.9815655,-28.09871,-29.2857647,-30.4454422,-31.3463821,-31.9966736,-32.51895,-33.07236,-33.4958458,-33.7865524,-34.1309662,-34.49548,-34.7051163,-35.05956,-35.28221,-35.51619,-35.803463,-36.0255165,-36.2064362,-36.3738823,-36.489357,-36.56496,-36.6248474,-36.6658,-36.72058,-36.7844429,-36.8479042,-36.9001732,-36.92281,-36.9599762,-36.9920959,-37.01288,-37.0343971,-37.04063,-37.0369835,-37.02857,-37.01347,-36.9903259,-36.971714,-36.9619026,-36.96348,-36.9586067,-36.95695,-36.96331,-36.9680634,-36.969265,-36.9741554,-36.98541,-36.9900551,-36.98191,-36.9605942,-36.9417534,-36.9312325,-36.921917,-36.9052048,-36.8591537,-36.830143,-36.758503,-36.6992874,-36.66629,-36.26225,-35.62142,-34.7001534,-33.9020081,-32.7896461,-31.3273315,-29.51747,-27.780407,-26.08436,-24.3930187,-22.3320217,-19.9161777,-17.96236,-15.9244738,-14.7959471,-13.47558,-12.0743561,-10.4428949,-9.280062,-8.141239,7.78311,7.779478,8.28875351,9.289248,10.4641638,11.302021,12.7094374,13.4113874,13.6849155,13.7988205,13.8418665,13.7839069,13.6932421,14.11501,14.9210129,15.8819351,17.2092533,18.637291,20.14612,21.0368633,21.7371731,22.168,22.8002853,24.6436043,25.75705,26.7386971,27.8088741,28.70764,31.27923,32.6712837,34.00964,34.98778,35.68681,37.0328064,37.7075958,39.41599,40.2484131,41.5681725,43.9930878,44.78017,46.21014,47.3522949,48.261467,49.42142,50.49801,51.15789,51.57304,51.8614273,52.1909142,52.5436478,52.8025169,53.0315323,53.10376,53.2067757,53.29872,53.3625031,53.40458,53.43079,53.480545,53.4946671,53.51369,53.56635,53.5749474,53.7846527,53.8733749,53.91401,53.91638,53.99815,54.0456734,54.09461,54.1437225,54.1977959,54.2171249,54.2462425,54.25589,54.2539558,54.1854553,54.16572,54.16595,54.1719475,54.19036,54.2021675,54.21054,54.2014961,54.21234,54.2343521,54.24616,54.25156,54.2522354,54.25113,54.2338257,54.217617,54.1734924,53.8893738,53.6176872,53.2605,52.074,51.0813522,48.6230278,46.1161461,43.4137154,40.411747,38.027298,36.43578,34.79242,33.4472542,30.1251812,27.9506588,26.48227,25.5702744,23.85928,23.0971718,21.7928944,20.8083973,19.056284,18.2309437,17.5452042,15.9150362,14.7183867,13.7420769,13.0188732,12.1550837,11.7002974,10.5331173,10.016181,9.161436,8.594983,7.43540144,6.737291,5.694676,5.09062147,4.76481152,-5.007112,-5.84039736,-7.0589695,-8.382486,-9.242949,-11.0220871,-12.0837879,-13.5011435,-16.1095963,-17.3143616,-19.11275,-19.8628845,-21.4376087,-22.12581,-23.8753338,-24.8288059,-26.1825638,-26.97862,-28.10256,-28.5856361,-29.43861,-29.92909,-30.3789272,-30.5753975,-30.8022346,-30.9868546,-31.1582718,-31.4626865,-31.7231083,-31.912468,-32.0983772,-32.27298,-32.37617,-32.5533752,-32.63729,-32.6913452,-32.7370071,-32.74641,-32.7871361,-32.8290672,-32.8458328,-32.851,-32.8687553,-32.8829842,-32.8971634,-32.914402,-32.94354,-32.961895,-32.9722862,-32.982,-32.9926834,-33.0050926,-33.018364,-33.0320778,-33.031498,-33.0299568,-33.0330467,-33.02398,-33.0156441,-33.00559,-33.003746,-32.9911537,-32.987648,-32.9845047,-32.9845123,-32.9829559,-32.97887,-32.9771729,-32.9776649,-32.97607,-32.9735832,-32.97746,-32.9773369,-32.98019,-32.9819756,-32.9859161,-32.99239,-32.9914551,-32.9973068,-32.9441032,-32.53864,-32.118885,-31.1956215,-30.6000328,-29.83491,-28.1042919,-26.9014778,-25.0183411,-23.9718781,-23.32345,-21.7936382,-20.9337215,-19.44472,-18.4942074,-17.1534481,-16.2430515,-14.4325771,-12.9471083,-10.3740692,-8.595098,-6.98061466,-6.082088,4.95428467,4.88342953,5.500001,6.284097,7.72283459,8.630284,9.555038,10.492857,11.2269487,12.0911922,13.3758411,13.7037268,14.166131,14.5942516,14.9360857,15.364193,16.2841835,17.4544048,18.7437782,19.7888947,22.0155,23.2500477,24.5230064,26.5185623,28.06866,30.0795727,32.5226555,34.0930748,35.4812279,37.8691025,39.04005,40.1855,41.901516,42.5463371,43.19976,43.91501,45.607605,46.2607574,46.75744,47.52221,48.2480164,49.3268661,50.0192146,50.2769737,50.86144,51.1204338,51.34375,51.6384,51.7455,51.84229,51.9374542,51.93936,51.900753,51.81386,51.7766342,51.7395859,51.7179031,51.7112427,51.7300873,51.7340851,51.73496,51.77417,51.8526535,51.90168,51.95463,52.00555,52.0788231,52.0552368,52.032196,51.9929466,51.90375,51.84191,51.80402,51.7406845,51.6843033,51.4460144,51.3693962,51.1316376,51.00333,50.8676872,50.805294,50.7447128,50.73673,50.7285271,50.68409,50.63424,50.5955048,50.5823555,50.644825,50.61454,50.5645142,50.4930458,50.24603,49.96432,49.3170052,48.2822266,45.8896065,44.5743942,43.11385,42.3353081,39.94572,37.9927444,35.6317978,34.07369,32.9218025,31.6056824,30.1828117,28.6710415,26.3899956,24.57902,23.1508236,22.365387,21.6836643,20.6931553,19.2221222,17.9648857,16.2642937,14.0984058,12.7167,11.8832712,10.88206,9.419119,8.412466,7.90502262,6.62498474,5.714123,3.84893584,3.06241274,2.24472022,-2.13780713,-2.64937139,-3.35788846,-4.876645,-6.535341,-8.04874,-9.958129,-10.72642,-12.1114569,-13.6261272,-15.375494,-16.6508121,-18.2452164,-19.2108,-20.9784489,-22.1047382,-23.4901142,-24.61645,-25.36283,-25.7363186,-26.74892,-27.3107681,-28.79243,-29.7298985,-30.8179817,-31.514698,-32.3788834,-32.86911,-33.2094955,-33.61881,-34.284668,-34.64234,-34.9445648,-35.2678452,-35.917717,-36.08323,-36.2092476,-36.3179131,-36.359417,-36.427742,-36.450264,-36.4676361,-36.4922256,-36.51325,-36.5227547,-36.53615,-36.5543671,-36.5600929,-36.5612869,-36.5563049,-36.55095,-36.54584,-36.5323639,-36.51747,-36.51091,-36.5004044,-36.4855347,-36.477,-36.47915,-36.48304,-36.47525,-36.46746,-36.46202,-36.45392,-36.45366,-36.44786,-36.4396172,-36.4269371,-36.42068,-36.4074631,-36.4020767,-36.3974,-36.39016,-36.38909,-36.38612,-36.382988,-36.3893776,-36.3967552,-36.40259,-36.3938026,-36.39471,-36.3922348,-36.38442,-36.3097458,-35.97997,-35.17139,-34.1038551,-32.9518433,-31.4953556,-29.7579155,-27.8025932,-26.0175781,-23.7609043,-22.2681751,-19.88396,-16.5616188,-14.4267664,-12.5322895,-9.814539,-8.267999,-5.524816,-4.44386864,-2.82223463,2.828678,3.68482733,4.76394749,6.83368635,7.870657,9.239632,10.118125,11.2350674,11.8909979,12.9958858,13.7449951,14.50146,15.631216,16.26505,18.275341,19.1407871,19.83592,21.218235,21.7016983,22.8830872,23.5141525,25.51254,26.1778183,27.21543,28.4217,30.1819363,31.9273987,33.1881752,34.32579,37.5630875,39.1245766,40.79793,42.6644173,44.90039,46.7637367,48.1835556,49.4034081,50.1541138,53.31304,54.16771,55.5751152,56.11515,57.354,57.86445,58.0857468,58.1178,58.115963,57.9976654,57.991333,57.9525566,57.867672,57.7363,57.5331078,57.46661,57.4491463,57.4804268,57.47521,57.48712,57.478878,57.49883,57.5129662,57.4782143,57.4669533,57.49445,57.51568,57.53697,57.5546455,57.5588379,57.6155357,57.8010445,57.8910179,58.00343,58.03713,58.0603523,58.1346,58.1659546,58.1977425,58.2004051,58.20798,58.2025032,58.2211533,58.2441254,58.20955,58.22168,58.2011566,58.1667252,58.0695648,57.9729576,57.8792419,57.80177,57.72639,57.6375237,57.56187,57.42248,57.24951,57.12113,56.9150238,56.862114,56.7114067,56.65491,56.43447,56.303566,55.73497,55.585,55.41204,54.7958679,53.77539,50.1692734,48.14935,44.5564537,41.0096436,39.883564,37.41378,36.45827,33.6541748,32.70629,30.9907684,28.867382,27.29528,25.22959,23.2599621,21.53627,20.1901379,18.3130074,15.7251263,14.1264181,13.2298412,12.08604,10.2229681,8.819534,6.96004343,6.09142828,4.506935,2.82008386,1.4295764,-1.0421139,-2.30757761,-4.532331,-7.12411547,-9.553824,-10.477562,-12.1909885,-13.1801481,-14.3082838,-16.792757,-18.4639187,-20.9814034,-22.4226227,-24.25723,-25.0724964,-26.5385876,-27.4205151,-28.7979622,-29.4134617,-30.4327888,-31.1865616,-32.2269173,-32.87388,-33.6639938,-34.656456,-35.0718231,-36.1292343,-36.5301,-37.0518837,-37.32895,-37.63742,-37.8287964,-38.06209,-38.1507339,-38.28626,-38.3316422,-38.37314,-38.4425545,-38.4777451,-38.4952,-38.51865,-38.55794,-38.5811043,-38.5926437,-38.6711655,-38.7093735,-38.7459221,-38.7801666,-38.7942047,-38.7987061,-38.8024673,-38.8051529,-38.81391,-38.8047142,-38.8133049,-38.8225174,-38.8413048,-38.8337021,-38.8345,-38.8366737,-38.83408,-38.81617,-38.8113022,-38.8006554,-38.7906876,-38.77632,-38.7622452,-38.74415,-38.74294,-38.7444344,-38.7498169,-38.7488556,-38.7484856,-38.7542152,-38.7600555,-38.7675858,-38.7544479,-38.7374344,-38.68366,-38.6508255,-38.54195,-38.4730949,-38.3678551,-37.7283554,-36.88451,-35.00339,-33.3441544,-31.6648083,-29.9371662,-28.58727,-26.3905487,-25.182909,-23.95109,-20.3726711,-18.3306828,-16.3401871,-13.0412607,-11.9763336,-9.639004,-7.90368176,-5.91112,-4.979254,4.696486,5.102577,6.29974031,7.3144,8.575973,10.2675714,10.7907991,11.7744484,12.3380423,13.4312057,14.0409355,15.0339823,18.1425667,18.6836052,19.4332867,20.5237885,21.928194,23.3427811,24.1894951,25.6770649,26.53505,27.7471676,29.00185,30.0214348,31.4345226,32.70823,33.64607,34.5200348,35.9025078,37.21327,38.1369476,39.9426,41.42551,42.68216,44.3665428,45.2441,45.8038673,46.3965759,47.55794,48.1055336,48.92102,50.3958473,51.4999275,51.9503326,52.2999573,52.4324532,52.55831,52.61942,52.70458,52.7587166,52.8412666,52.90058,52.91166,52.9248428,52.93227,52.9333038,52.9304657,52.9288559,52.9105339,52.91484,52.9165268,52.91899,52.9214134,52.9334526,52.9391174,52.9635773,52.9832878,52.98689,53.01689,53.0212059,53.0138321,52.999157,52.996563,53.01393,53.115696,53.216198,53.29271,53.3147545,53.3395653,53.3593025,53.3904152,53.4720268,53.5326653,53.5874519,53.6313171,53.6421242]

# %%
timestamps = [0.014701,0.0337057,0.0504039,0.0664891,0.0840161,0.1010388,0.1181909,0.1355183,0.146306,0.165593,0.1823978,0.1988752,0.2165996,0.2338242,0.2502551,0.2665072,0.282890916,0.298879027,0.318200022,0.333708823,0.349065036,0.365953535,0.385228723,0.401987016,0.417918324,0.4331532,0.4495126,0.4651572,0.4855704,0.5020766,0.519108951,0.53556025,0.548807144,0.5694652,0.5820396,0.6015671,0.6177618,0.6338229,0.6502334,0.6658498,0.6829736,0.698785543,0.719038546,0.735542953,0.751124561,0.765818238,0.7852224,0.8011619,0.8162651,0.8318029,0.8494432,0.8651518,0.883293033,0.900526345,0.91756475,0.934262156,0.95099324,0.967854559,0.985014558,1.00214481,1.01620626,1.03440082,1.04816043,1.065355,1.08336771,1.09827459,1.11749053,1.13614058,1.15167522,1.16434586,1.18431139,1.19859254,1.21952629,1.229433,1.25016487,1.265278,1.28126264,1.3035655,1.31504846,1.33424485,1.34979463,1.36555755,1.3880105,1.39901483,1.41991115,1.43164182,1.44752932,1.46571743,1.47899389,1.50275433,1.51572978,1.53151309,1.550492,1.5678966,1.58573282,1.59729183,1.61878765,1.63563144,1.65043342,1.66199088,1.68514585,1.70645463,1.72482169,1.740568,1.75574374,1.77094793,1.78538835,1.80048847,1.82425141,1.84445846,1.86166668,1.87832689,1.89266682,1.91006756,1.92650771,1.94389117,1.96172547,1.98150754,1.99900091,2.01567364,2.030321,2.046881,2.06272,2.07888913,2.10144114,2.11717582,2.13124824,2.14531136,2.168476,2.18250632,2.198813,2.21681547,2.23566628,2.255224,2.27570033,2.29300117,2.31302166,2.334449,2.355463,2.3745594,2.392591,2.41030622,2.429532,2.44637322,2.465508,2.48582315,2.50755262,2.52650785,2.5450356,2.5649457,2.582227,2.603974,2.62787127,2.647217,2.66748738,2.68990779,2.7110045,2.73218417,2.75722861,2.78100538,2.80587077,2.83183217,2.85735488,2.88351,2.90822124,2.93321824,2.95326042,2.97881365,3.00236,3.03801918,3.06328249,3.08741164,3.11326432,3.14018345,3.161438,3.17926526,3.19862056,3.22023964,3.27195263,3.30046463,3.324677,3.35085225,3.37196422,3.39551353,3.41478872,3.434747,3.453012,3.48997855,3.51084733,3.53422165,3.55279946,3.5868175,3.606811,3.63945913,3.67572856,3.6983,3.72660875,3.74876285,3.77860355,3.81075048,3.83544278,3.86952639,3.89114237,3.924956,3.95398951,3.97865939,4.00916862,4.049194,4.0769763,4.111935,4.13521671,4.16540241,4.20221567,4.22763968,4.255624,4.30339861,4.3285737,4.350299,4.3672843,4.406554,4.45053244,4.471991,4.502847,4.522621,4.55617142,4.603044,4.62706566,4.65453768,4.676047,4.712157,4.7323885,4.76580238,4.78598642,4.8209343,4.867849,4.887808,4.91397524,4.93202639,4.96468163,4.98386049,5.020477,5.04088259,5.07692575,5.09585476,5.13283062,5.15574932,5.1793375,5.19914436,5.2183013,5.234297,5.2502985,5.26791763,5.28436661,5.300424,5.315781,5.33956146,5.35794,5.37385559,5.388333,5.404548,5.418712,5.43314648,5.455758,5.47313643,5.48753643,5.50185061,5.524232,5.540852,5.55892,5.57396936,5.59032774,5.60591841,5.6226306,5.63987541,5.658781,5.676138,5.69317245,5.71044874,5.72588348,5.742011,5.75858927,5.775068,5.79125166,5.80699,5.82349539,5.841379,5.85835028,5.876555,5.89251375,5.90877,5.92477226,5.94495344,5.96137142,5.98898268,6.00870562,6.02763176,6.04503775,6.06675863,6.0866437,6.10752773,6.126741,6.14552069,6.16623449,6.18549061,6.20341539,6.221317,6.24038649,6.259471,6.277445,6.29423,6.309553,6.325009,6.340539,6.35675669,6.37078762,6.3863554,6.40231228,6.418095,6.4404974,6.460005,6.478271,6.49692154,6.51183176,6.53133535,6.54921246,6.56667662,6.586132,6.605833,6.62204027,6.638361,6.655025,6.671867,6.687696,6.703021,6.71879435,6.734764,6.757004,6.775445,6.79008436,6.803818,6.81969833,6.8433795,6.860965,6.87789965,6.894619,6.910331,6.92708063,6.94305754,6.960914,6.977647,6.99386644,7.01087856,7.029852,7.048396,7.06647062,7.08409166,7.10005426,7.114793,7.130746,7.14759541,7.1647563,7.189259,7.20709658,7.22304869,7.23920059,7.25566626,7.27137947,7.28576851,7.302442,7.318549,7.33314228,7.356362,7.372654,7.38784027,7.40225029,7.41775656,7.43895626,7.45699024,7.473724,7.48944426,7.50561428,7.52165747,7.537133,7.553571,7.56980038,7.58579874,7.60160875,7.62705946,7.64436865,7.65958738,7.67491865,7.69013834,7.704818,7.72100163,7.73556137,7.75038242,7.775788,7.79209948,7.80613375,7.81994152,7.834047,7.85890961,7.878356,7.89559555,7.912803,7.930255,7.94958258,7.96845341,7.98578453,8.007368,8.02461,8.042854,8.060654,8.07899952,8.097343,8.113289,8.13027,8.145374,8.163148,8.180444,8.195993,8.215747,8.233051,8.250824,8.27144,8.294049,8.314181,8.334328,8.354982,8.379257,8.399139,8.418136,8.435669,8.456287,8.472873,8.489633,8.5054,8.52386951,8.538946,8.556367,8.576571,8.592234,8.608955,8.625214,8.642114,8.658829,8.675693,8.692788,8.711432,8.728337,8.745792,8.761866,8.778434,8.795008,8.811537,8.829103,8.844651,8.860822,8.877896,8.895618,8.913064,8.931129,8.958452,8.976098,8.991609,9.006072,9.021499,9.037248,9.051777,9.073203,9.09686852,9.112339,9.131525,9.146839,9.163105,9.180991,9.200075,9.216954,9.233399,9.25158,9.269591,9.287125,9.302833,9.317484,9.339538,9.356665,9.37152,9.385557,9.400591,9.42233,9.441854,9.457728,9.475992,9.492131,9.509222,9.526708,9.545682,9.561308,9.579748,9.597418,9.613941,9.629827,9.646863,9.663453,9.680341,9.696554,9.712007,9.72971249,9.754304,9.771669,9.786484,9.805231,9.820189,9.83568,9.850162,9.874567,9.891847,9.906823,9.922246,9.938312,9.95392,9.970239,9.984928,9.999266,10.0154018,10.0321913,10.04857,10.0744553,10.0922813,10.1080971,10.1228638,10.1370115,10.1610146,10.174737,10.1889849,10.2021141,10.2178288,10.2389317,10.2547855,10.2696724,10.2868052,10.3015947,10.3249893,10.3414373,10.35582,10.368885,10.3863859,10.411974,10.4293213,10.4445477,10.4629784,10.4803085,10.4967279,10.5147362,10.5316858,10.5482283,10.5624342,10.5774632,10.59184,10.606883,10.630331,10.6429434,10.6635618,10.67869,10.6946,10.7109766,10.7293272,10.74589,10.7636528,10.7834349,10.7981691,10.8154793,10.8339615,10.848959,10.8649187,10.8808641,10.9071293,10.9239521,10.9386663,10.9530172,10.9703426,10.9840622,11.0044174,11.0196486,11.0403709,11.0743685,11.0902376,11.103097,11.11825,11.1373606,11.1514044,11.1699533,11.18422,11.206192,11.2237339,11.2399063,11.2549076,11.2704973,11.284976,11.3054533,11.3226938,11.3367558,11.3593559,11.3730631,11.3878822,11.4109764,11.4260378,11.4406109,11.4548235,11.4685383,11.49196,11.5077705,11.5221376,11.537343,11.5516043,11.5714464,11.5882235,11.6033,11.6198425,11.6426477,11.6568489,11.6722527,11.6870766,11.70942,11.7247019,11.7377157,11.7601357,11.7729378,11.7877541,11.8019238,11.8219252,11.8375149,11.8580923,11.8704872,11.8919592,11.9048491,11.9264278,11.9383736,11.958931,11.9727211,11.9860973,12.0058765,12.0196495,12.0398273,12.0578651,12.0706358,12.0914059,12.1038342,12.1180887,12.1399431,12.155201,12.1754494,12.1872959,12.2080488,12.2199306,12.2423067,12.2550154,12.274436,12.28772,12.3076754,12.3198185,12.3401012,12.3566971,12.3747053,12.3893986,12.4045544,12.4200754,12.43574,12.460433,12.4759436,12.4917593,12.5075188,12.5231819,12.5379686,12.5607643,12.575489,12.5904894,12.6054316,12.6208019,12.6374149,12.6544266,12.6699505,12.6865816,12.7126226,12.7267971,12.7401476,12.7541647,12.7770119,12.7893248,12.8045244,12.8195477,12.8441267,12.8591518,12.8715305,12.8931427,12.9066086,12.9287949,12.9440327,12.9571085,12.9730043,12.99046,13.0040913,13.0270405,13.0411005,13.0547628,13.0792913,13.0930328,13.1068087,13.1218739,13.1467857,13.1608763,13.17551,13.1913662,13.2076626,13.2225313,13.240346,13.2555666,13.2719278,13.2954788,13.3095388,13.322731,13.3451138,13.3584728,13.3806133,13.39273,13.40579,13.4272318,13.4406519,13.4622555,13.47591,13.4898214,13.510458,13.5228024,13.5427294,13.5565042,13.5777779,13.5903511,13.6101761,13.6244,13.6454086,13.6595049,13.6790714,13.6915636,13.711709,13.72442,13.7458277,13.7593384,13.7807455,13.79362,13.8093863,13.82486,13.8394575,13.8552771,13.8806934,13.8965836,13.9130077,13.9293451,13.9463882,13.9637194,13.9805679,13.9977322,14.0126209,14.0265455,14.0475445,14.062479,14.0767641,14.0995131,14.113327,14.1277485,14.1484375,14.1620016,14.1750469,14.1967611,14.2107277,14.225421,14.2470036,14.2600441,14.2794313,14.293292,14.3141537,14.3270245,14.341773,14.3633261,14.3757629,14.3967619,14.4157162,14.4288788,14.4494238,14.4636517,14.476,14.4960146,14.5082512,14.5288963,14.5417681,14.5637236,14.5765247,14.5964909,14.6094713,14.631835,14.6482611,14.6637974,14.6787844,14.6935987,14.707263,14.7238626,14.7504158,14.7671623,14.7868853,14.8081942,14.8271112,14.8436556,14.8616648,14.8801937,14.8984318,14.9145174,14.9288864,14.9422379,14.9563046,14.97802,14.9919748,15.01325,15.0268745,15.0412912,15.0562057,15.0794125,15.0927839,15.1060534,15.127593,15.140521,15.1608706,15.17379,15.1942663,15.2081585,15.2290239,15.2406836,15.2622948,15.2743845,15.2937994,15.3080416,15.3279581,15.3405294,15.3614178,15.3732271,15.3934107,15.4060545,15.4259329,15.4463282,15.461256,15.477088,15.4914494,15.50614,15.5300894,15.54491,15.5614395,15.5761023,15.5912352,15.6064215,15.6237974,15.6398745,15.6571722,15.6820726,15.6969757,15.7114248,15.7246561,15.7473316,15.7618933,15.7755,15.7956171,15.8085451,15.8302212,15.8440475,15.8578749,15.88232,15.8952188,15.9071922,15.9274988,15.94803,15.9596186,15.9813976,15.99367,16.0142155,16.0259247,16.0458012,16.057909,16.078516,16.0905247,16.1113777,16.1240482,16.14427,16.1644,16.1790543,16.19134,16.2120323,16.2241917,16.2440529,16.2566147,16.2783642,16.2923679,16.3136711,16.3272133,16.342123,16.3574429,16.381937,16.3980961,16.41332,16.4289055,16.46541,16.4823284,16.4987946,16.5131435,16.5285168,16.55201,16.5672569,16.5798416,16.5952282,16.6179161,16.6318016,16.6460533,16.66838,16.6822262,16.6948071,16.716608,16.7294216,16.7437782,16.7637253,16.78483,16.7981262,16.81062,16.8314114,16.8443,16.8647213,16.8784428,16.8985081,16.9136868,16.9284611,16.95186,16.9674358,16.9811535,16.9961834,17.0112114,17.0261269,17.0467834,17.0669613,17.0802536,17.1008453,17.1143055,17.1269531,17.1474571,17.16739,17.1801262,17.1999,17.21699,17.23336,17.2512932,17.2669621,17.285099,17.3010883,17.31757,17.3347034,17.3520412,17.3708649,17.3879261,17.4047031,17.41989,17.44282,17.4582977,17.4733124,17.4886627,17.5047569,17.5187378,17.5389729,17.5520344,17.5722656,17.5855732,17.6062717,17.6200485,17.6397133,17.6528778,17.67476,17.68696,17.7062855,17.71858,17.7401428,17.7522087,17.7736626,17.7871933,17.8015423,17.8195171,17.83345,17.85869,17.8735123,17.8849678,17.9037113,17.9190121,17.93887,17.951643,17.9727325,17.9887657,18.00277,18.0166035,18.0368938,18.0528221,18.0692062,18.084753,18.1061649,18.1223984,18.1385155,18.1544456,18.16976,18.1865616,18.2032471,18.218771,18.2341042,18.2548523,18.2717228,18.2853642,18.30107,18.3220329,18.33932,18.35594,18.3693428,18.3840618,18.41101,18.4264946,18.4387,18.4582653,18.471014,18.49137,18.5042953,18.5235558,18.5361748,18.5568466,18.5700169,18.5889816,18.60731,18.619339,18.6397648,18.6517811,18.6761589,18.6907024,18.7018623,18.7227535,18.7424183,18.7541485,18.7762127,18.788229,18.8093987,18.8216763,18.8351727,18.8534031,18.8715076,18.8871231,18.90194,18.9176254,18.9389782,18.9540367,18.9688416,18.9916573,19.0058384,19.02152,19.0381145,19.0558071,19.0725918,19.08832,19.104351,19.1194973,19.14443,19.1605415,19.1767063,19.1904354,19.2048264,19.2262459,19.2392578,19.26068,19.2730122,19.294,19.3071728,19.32787,19.3406754,19.3598461,19.3746777,19.387167,19.4079514,19.4207153,19.4412022,19.4611378,19.4735336,19.49259,19.5047722,19.5253658,19.5375328,19.5565472,19.5773087,19.5904789,19.6095753,19.6218033,19.640995,19.6538181,19.6736813,19.6945381,19.7098217,19.72396,19.7383156,19.7609959,19.7752533,19.7912312,19.8058739,19.8208542,19.83826,19.8536968,19.87736,19.89296,19.9073868,19.92119,19.9446316,19.9566288,19.97738,19.9909611,20.0039883,20.025938,20.0388184,20.0593948,20.07346,20.0946045,20.1073036,20.1276226,20.1393433,20.1596222,20.1723251,20.1911526,20.2056255,20.2273922,20.2389145,20.2577515,20.277256,20.2892532,20.3144417,20.3255558,20.3434067,20.356863,20.37652,20.3899078,20.4114666,20.4232311,20.4431725,20.4558868,20.4711437,20.4922638,20.5062733,20.527895,20.5438633,20.55964,20.574955,20.58828,20.60922,20.6220665,20.6367435,20.6588936,20.67297,20.6871929,20.7087746,20.7246132,20.7398567,20.7536736,20.7747269,20.7956944,20.8102379,20.8245354,20.8447437,20.8573742,20.8708019,20.893816,20.9061584,20.92535,20.9388123,20.9611187,20.9745274,20.992939,21.0121555,21.0238228,21.042593,21.0547619,21.07428,21.09381,21.1070881,21.1267052,21.1413212,21.1546936,21.1769047,21.1890278,21.209774,21.2243538,21.23814,21.2606678,21.27365,21.2954216,21.3098,21.3238888,21.34412,21.35636,21.3769951,21.3894272,21.4049644,21.4426327,21.4587326,21.47504,21.4993248,21.5138435,21.5293751,21.54318,21.5656586,21.5794315,21.5937576,21.6077824,21.63097,21.64425,21.6583576,21.6801,21.6934719,21.71388,21.7265568,21.7482586,21.7599983,21.7740326,21.802,21.8158283,21.8260517,21.8451843,21.8634758,21.882328,21.89377,21.9132729,21.9272842,21.9469967,21.9666233,21.978611,21.99811,22.0166283,22.0291862,22.0422688,22.061903,22.0801945,22.0918541,22.11194,22.1310558,22.1446381,22.16712,22.1798115,22.193718,22.2158432,22.230648,22.2438812,22.2583218,22.2798767,22.2970753,22.3123627,22.3268375,22.34254,22.3685246,22.3860149,22.3993187,22.4112282,22.4363232,22.4530525,22.4699955,22.4869328,22.50256,22.5167923,22.5364075,22.55067,22.5687752,22.5832634,22.60221,22.6170235,22.634367,22.6471977,22.6601372,22.6805782,22.7002525,22.712183,22.7333927,22.7455635,22.7648335,22.7777119,22.7978325,22.81064,22.83003,22.8496151,22.86871,22.8821545,22.9000511,22.9117813,22.9300938,22.9514847,22.9636631,22.9773483,22.9983025,23.0118313]

# %%
timeStampDifferences = []

for i in range(len(timestamps) - 1):
    timeStampDifferences.append(timestamps[i + 1] - timestamps[i])

plt.hist(timeStampDifferences, bins=100)
plt.title('Difference between timestamps histogram')
plt.xlabel('Time between timestamps (s)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
zeroToOne = 0
OnetoTwo = 0 
for i in range(len(timestamps)):
    if timestamps[i] <= 1:
        zeroToOne += 1
    elif timestamps[i] >= 1 and timestamps[i] <= 2:
        OnetoTwo += 1

# %%
1/60
# Out:
# 0.016666666666666666

# %%
plt.plot(timestamps, angles)
plt.title('Raw Angles - Standard Movement')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
min_angles = [-39.64021,-37.04063,-33.0330467,-36.5612869,-38.8413048]
min_tstmps = [5.234297,8.958452,12.9440327,16.6948071,20.8102379]
max_angles = [56.0897179,54.25589,52.0788231,58.2441254]
max_tstmps = [7.23920059,11.0196486,14.8271112,18.9688416]

# %%
plt.plot(timestamps, angles)
plt.plot(max_tstmps, max_angles, 'ro')
plt.plot(min_tstmps, min_angles, 'go')
plt.legend(['angles', 'max angles', 'min angles'])
plt.title('Max and Min Angles Achieved')
# Out:
# Text(0.5, 1.0, 'Max and Min Angles Achieved')

# %%
# Convert angles to angular velocities
def calculate_angular_velocities(angles: np.ndarray, timestamps: np.ndarray) -> np.ndarray:
    """
    Calculates the angular velocities based on the given angles and timestamps.

    Args:
    angles (np.ndarray): An array of angles in radians.
    timestamps (np.ndarray): An array of timestamps in seconds.

    Returns:
    np.ndarray: An array of angular velocities in radians per second.
    """
    time_diff = np.diff(timestamps)
    angle_diff = np.diff(angles)
    angular_velocities = angle_diff / time_diff
    return angular_velocities

# %%
import matplotlib.pyplot as plt

ang_vel = calculate_angular_velocities(angles, timestamps)
fig, ax1 = plt.subplots()

# Plot the smoothed angles on the left-hand side y-axis
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Unsmoothed Angles (deg)', color='tab:blue')
ax1.plot(timestamps, angles, color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for the angular velocity
ax2 = ax1.twinx()
ax2.set_ylabel('Angular Velocity (deg/s)', color='tab:orange')  
ax2.plot(timestamps[0:-1], ang_vel, color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title('Angular Velocities (UnSmoothed Angles)')
plt.show()

# %%
# Pad and Calculate fourier coeffs + angles
ang_vel_padded = np.pad(ang_vel, (0, int(2**(np.ceil(math.log(len(ang_vel),2))+4)-len(ang_vel))))

fourier_coeffs = np.fft.fft(ang_vel_padded)
fourier_mag = np.abs(fourier_coeffs)
N = len(fourier_mag)

fourier_mag_adj = fourier_mag / fourier_mag[0]

# Restrict to range we care about
sampling_rate = 1/60
freqs = np.fft.fftfreq(N, sampling_rate)

freqs_restricted = freqs[:N//2]

# Get the restricted frequency range
for i in range(len(freqs_restricted)):
    if freqs_restricted[i] > 7:
        freqs_restricted = freqs_restricted[:i]
        fourier_mag_restricted = fourier_mag_adj[:i]
        break

plt.plot(freqs_restricted[:N//2], fourier_mag_restricted[:N//2])  # Plotting only the positive frequencies
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Fourier Magnitude Spectrum")
plt.show()

# %%
# Default smoothness measure
smoothness_measure = 0

for i in range(len(freqs_restricted)-1):
    smoothness_measure -= math.sqrt( (1 / (len(freqs_restricted) - 1)) ** 2 + (fourier_mag_restricted[i+1] - fourier_mag_restricted[i]) ** 2 )

smoothness_measure
# Out:
# -96.43310337040076

# %%
def moving_average_angles(angles: np.ndarray, moving_average_window: int) -> np.ndarray:
    """
    Calculates the moving average of the given array of angles.

    Args:
    angles (np.ndarray): An array of angles in radians.
    moving_average_window (int): The size of the moving average window.

    Returns:
    np.ndarray: An array of the moving average of the input angles.
    """
    return np.convolve(angles, np.ones(moving_average_window) / moving_average_window, mode='valid')

# %%
smoothed_angles = moving_average_angles(angles, 4)
plt.plot(timestamps[1:-2], smoothed_angles)
plt.title('Smoothed Angles')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
import matplotlib.pyplot as plt

ang_vel = calculate_angular_velocities(smoothed_angles, timestamps[1:-2])

fig, ax1 = plt.subplots()

# Plot the smoothed angles on the left-hand side y-axis
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Smoothed Angles (deg)', color='tab:blue')
ax1.plot(timestamps[1:-2], smoothed_angles, color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for the angular velocity
ax2 = ax1.twinx()
ax2.set_ylabel('Angular Velocity (deg/s)', color='tab:orange')  
ax2.plot(timestamps[2:-2], ang_vel, color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title('Angular Velocities (Smoothed Angles)')
plt.show()

# %%
# Pad and Calculate fourier coeffs + angles
ang_vel_padded = np.pad(ang_vel, (0, int(2**(np.ceil(math.log(len(ang_vel),2))+4)-len(ang_vel))))

fourier_coeffs = np.fft.fft(ang_vel_padded)
fourier_mag = np.abs(fourier_coeffs)
N = len(fourier_mag)

fourier_mag_adj = fourier_mag / fourier_mag[0]

# Restrict to range we care about
sampling_rate = 1/60
freqs = np.fft.fftfreq(N, sampling_rate)

freqs_restricted = freqs[:N//2]

# Get the restricted frequency range
for i in range(len(freqs_restricted)):
    if freqs_restricted[i] > 7:
        freqs_restricted_smooth = freqs_restricted[:i]
        fourier_mag_restricted_smooth = fourier_mag_adj[:i]
        break

plt.plot(freqs_restricted_smooth[:N//2], fourier_mag_restricted_smooth[:N//2])  # Plotting only the positive frequencies
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Fourier Magnitude Spectrum, smoothed angles")
plt.show()

# %%
# Pad and Calculate fourier coeffs + angles
ang_vel_padded = np.pad(ang_vel, (0, int(2**(np.ceil(math.log(len(ang_vel),2))+4)-len(ang_vel))))

fourier_coeffs = np.fft.fft(ang_vel_padded)
fourier_mag = np.abs(fourier_coeffs)
N = len(fourier_mag)

fourier_mag_adj = fourier_mag / fourier_mag[0]

# Restrict to range we care about
sampling_rate = 1/60
freqs = np.fft.fftfreq(N, sampling_rate)

freqs_restricted = freqs[:N//2]

# Get the restricted frequency range
for i in range(len(freqs_restricted)):
    if freqs_restricted[i] > 7:
        freqs_restricted = freqs_restricted[:i]
        fourier_mag_restricted = fourier_mag_adj[:i]
        break

plt.plot(freqs_restricted[:N//2], fourier_mag_restricted[:N//2])  # Plotting only the positive frequencies
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Fourier Magnitude Spectrum, smoothed angles")
plt.show()

# %%
# Default smoothness measure
smoothness_measure = 0

for i in range(len(freqs_restricted)-1):
    smoothness_measure -= math.sqrt( (1 / (len(freqs_restricted) - 1)) ** 2 + (fourier_mag_restricted[i+1] - fourier_mag_restricted[i]) ** 2 )

smoothness_measure
# Out:
# -99.01494872668177

# %%
angles = [1.96483243,1.93987191,1.91540408,1.8969233,1.87826085,1.84959686,1.82477689,1.80004966,1.78717458,1.77861273,1.75813937,1.73641062,1.72169685,1.71383584,1.7059387,1.69223237,1.67257416,1.65812027,1.63709664,1.61398208,1.58313215,1.55859029,1.48213351,1.436677,1.39997625,1.35219455,1.283137,1.25476217,1.23289382,1.21563125,1.19762981,1.18679678,1.19091177,1.18893838,1.16717827,1.12535346,1.0660615,0.9974037,0.9346082,0.893067241,0.8497278,0.8055148,0.7522548,0.67839694,0.5811456,0.5410409,0.46435985,0.416371018,0.397620946,0.3995845,0.420579284,0.4463111,0.497321934,0.499285281,0.500068545,0.520769835,0.5177552,0.5226451,0.52971077,0.5286014,0.53595376,0.545722246,0.5784457,0.5706123,0.5482264,0.5047422,0.435212553,0.375865161,0.309643,0.251788318,0.221173435,0.195835277,0.149353445,-0.03426402,-0.102792077,-0.164324522,-0.203671768,-0.2102893,-0.2121421,-0.228141233,-0.264669925,-0.2556444,-0.242283374,-0.236562565,-0.239848316,-0.260947227,-0.269069165,-0.253337771,-0.266878635,-0.288035542,-0.318981081,-0.3769049,-0.4329587,-0.5263757,-0.6510199,-0.732486069,-0.8060005,-0.8343908,-0.855236769,-0.846266568,-0.833686948,-0.8221055,-0.8221055,-0.8057577,-0.800152659,-0.798929,-0.8055148,-0.8045425,-0.7979487,-0.7875819,-0.747296154,-0.734353662,-0.7138155,-0.7113441,-0.7132671,-0.7154584,-0.718188167,-0.7292733,-0.7359507,-0.7359507,-0.735152662,-0.7316842,-0.7252374,-0.7252374,-0.70025456,-0.6419396,-0.6145305,-0.5464389,-0.537412167,-0.537412167,-0.564406037,-0.6119779,-0.6611602,-0.7135413,-0.7438844,-0.7561465,-0.7576976,-0.7561465,-0.7506924,-0.7850935,-0.8098756,-0.8638874,-0.9940628,-1.05034339,-1.10606062,-1.11047482,-1.0970006,-1.09038055,-1.07410753,-1.0719192,-1.094858,-1.10411274,-1.11890113,-1.1303848,-1.13315129,-1.14637125,-1.18001723,-1.20917511,-1.27686882,-1.32189834,-1.36185622,-1.40207136,-1.41968632,-1.43899071,-1.45239151,-1.47179878,-1.45602489,-1.46232808,-1.453065,-1.446451,-1.4336772,-1.326627,-1.29679,-1.269183,-1.21176159,-1.176696,-1.1560601,-1.169021,-1.16985774,-1.16466069,-1.16583622,-1.17486513,-1.18811512,-1.2070694,-1.21723986,-1.23495543,-1.26315558,-1.29089141,-1.274875,-1.2489785,-1.2313056,-1.20398521,-1.17052662,-1.12899911,-1.09289026,-1.03722024,-0.998971939,-0.9366996,-0.902873337,-0.860255659,-0.824956834,-0.7648944,-0.717643,-0.6205508,-0.5983981,-0.5944612,-0.8030819,-1.31224072,-1.871685,-3.505205,-5.34104061,-5.98978662,-6.622705,-6.56459045,-6.34106064,-6.73816442,-8.042445,-10.4006815,-12.9874544,-14.2232027,-15.60045,-16.2661228,-19.671814,-21.4591827,-23.7221,-24.54592,-24.8444328,-25.15785,-26.195509,-27.8868389,-29.49399,-31.4558868,-33.8574753,-34.14365,-34.42899,-36.0881042,-36.80515,-37.3454742,-37.9603424,-38.0191154,-38.46361,-38.69828,-39.01136,-39.1513062,-39.3636551,-39.5341339,-39.52182,-39.5522346,-39.76464,-39.860405,-40.0967064,-40.29904,-40.7057,-41.2057838,-41.48187,-42.0782852,-42.3774261,-42.90173,-43.215683,-43.68516,-44.1688,-44.33019,-44.50466,-44.5587,-44.5249,-44.41459,-44.27099,-44.25069,-44.16395,-44.0930824,-44.0179634,-43.88485,-43.79336,-43.73159,-43.71051,-43.65582,-43.6348457,-43.55834,-43.3925323,-43.2714539,-43.18632,-43.0712967,-42.99204,-42.96311,-42.9213066,-42.9069633,-42.8580322,-42.8202057,-42.7982635,-42.722477,-42.6729774,-42.6098671,-42.58904,-42.56748,-42.5233536,-42.284668,-42.02522,-41.63304,-41.023037,-40.3219948,-39.0344925,-38.00554,-37.5735931,-36.2073021,-35.30085,-34.6363831,-34.22931,-34.0378647,-33.69555,-33.5140648,-33.2024231,-32.61092,-31.3367882,-30.0513134,-26.1111126,-24.0600758,-23.33086,-22.8639431,-21.6089134,-20.2234383,-17.4213333,-15.0077066,-12.3803406,-11.2507439,-10.1202431,-9.629209,-9.346157,-8.481143,-7.868437,-5.67025661,-5.407801,-5.17111969,4.95531273,5.0621376,5.992535,6.66200161,6.90486956,7.47401571,7.770718,8.124292,7.81539774,8.139334,8.776105,9.26321,9.86125,11.6139612,12.968462,14.2787638,14.7730217,15.0967607,16.1446114,17.9926224,18.9403648,20.9762173,23.4970531,25.0122375,26.7355175,28.9739189,30.2132969,31.5263786,33.0716,33.9065247,34.4466133,35.18703,35.8205566,36.9092674,37.62095,39.2699432,39.9885139,42.95693,44.3645935,45.5213242,47.46897,48.5671921,49.1468468,49.5448532,50.0604057,50.70758,51.16375,51.347084,51.3314133,51.34003,51.2207832,51.26749,51.4010658,51.577713,52.35673,52.7180061,53.3326836,53.6945038,53.861084,53.7873421,53.424202,53.29453,53.32943,53.8076248,53.8602257,53.8546677,53.919838,53.8530731,53.83169,53.8000679,53.78566,53.73003,53.7321167,53.56752,53.30523,52.8385429,52.68394,52.5457344,52.4398842,52.2540436,52.10485,51.8327255,51.59374,51.33401,50.72282,50.0199623,48.3511848,47.0485649,44.95351,42.34253,40.53766,39.1696129,38.4777565,37.91174,37.6462173,37.23117,32.93105,29.3185329,27.0517311,25.73483,25.0352535,24.9234581,21.756197,18.8477135,12.7041435,11.251339,9.217123,7.82847166,6.439159,5.70183,4.91765,2.86539364,-2.69340873,-2.987603,-4.35667,-5.64927149,-7.88154745,-8.831954,-10.1107931,-11.0719376,-11.8181667,-12.6816216,-13.2784758,-14.6597338,-15.9781437,-18.0931816,-18.9695816,-20.6216621,-21.2638588,-22.3332958,-23.2470112,-24.1963539,-24.6113167,-25.4718437,-27.1258335,-28.0661354,-29.1594238,-30.0821,-31.11676,-32.40144,-33.329422,-33.9833946,-34.8157463,-35.7611961,-36.56876,-38.400528,-38.9299965,-39.5008659,-39.73,-40.2944832,-40.939415,-41.5151138,-41.9487877,-42.0541,-42.28652,-42.6384125,-43.13702,-43.5028534,-43.50906,-43.3734245,-42.5469246,-42.1918869,-42.6325951,-42.8262444,-42.83469,-42.63791,-42.04554,-41.92463,-41.9766769,-42.25153,-42.4940872,-43.0584259,-42.9721,-42.7364349,-42.27258,-42.0830154,-42.5612946,-42.68406,-42.8934326,-42.79983,-42.6968079,-42.59461,-42.6240845,-42.8733826,-43.0128021,-43.104435,-43.046627,-42.6448822,-42.4620934,-42.460556,-42.4764557,-42.5846939,-42.741272,-42.7732,-42.9550171,-43.13951,-43.222065,-43.2443581,-43.21019,-43.0153465,-42.98958,-43.3695221,-43.46748,-43.5219421,-43.53275,-43.5647736,-43.6135559,-43.5998726,-43.4474373,-43.401,-43.374958,-43.3786125,-43.40307,-43.4257736,-43.522644,-43.6564941,-43.67621,-43.6747932,-43.6850929,-43.73659,-43.8965645,-44.0424843,-43.9759827,-43.8742638,-43.786396,-43.3149261,-42.24792,-40.1233139,-39.0640259,-38.19476,-36.2777557,-35.49523,-34.2938423,-31.1058216,-29.6412582,-28.0794659,-27.3591843,-26.88107,-24.7085476,-22.6576424,-21.0454521,-19.2708035,-17.3731213,-14.72262,-13.6882925,-12.5096369,-11.8057213,-10.6604385,-9.288656,-7.996031,-6.97077274,-6.356533,6.125511,6.151126,6.204124,6.56641245,6.708381,6.88538361,7.34296656,7.995294,8.642952,9.980776,11.6768818,12.8526945,13.8565044,15.149682,15.9992456,17.4373055,18.3101826,20.7773628,22.3999062,23.8447533,25.003891,25.6056042,25.7982,25.8088074,25.76123,27.1259251,29.1770763,30.9307365,32.31891,33.89603,34.9568558,35.8548126,36.81819,37.4734459,38.337326,39.109,40.37603,41.7966,43.06497,44.03773,45.92582,46.5081367,48.6965332,49.404953,49.2213,48.8849945,48.85489,49.04562,49.87717,50.24069,51.44718,51.5682449,51.61562,51.6342468,51.7933,52.0321274,52.4257927,53.0685768,53.23257,53.32694,53.27292,53.17852,53.1611748,53.6486855,53.88339,53.98442,53.87285,53.8281174,53.79931,53.79763,53.79751,53.70334,53.65098,53.61172,53.7594452,53.79539,53.68287,53.3550835,52.77767,51.81297,51.2670479,50.6507263,49.37845,47.629364,44.7431679,42.83725,41.8866425,41.8842163,41.86789,41.718956,40.46601,34.5723572,31.2517662,25.89947,24.3339348,23.3393421,22.6197853,21.3054333,18.0981617,17.5427685,16.779192,15.8341064,10.4751778,9.1924,7.310456,6.49497938,6.087372,5.5711956,5.277152,4.99951553,4.355321,3.073452,2.67071128,2.08994,1.84472334,1.80515218,-1.87116218,-1.90567255,-2.49598885,-3.56579018,-5.09081364,-6.2429347,-8.358276,-9.83161449,-12.134841,-13.1658964,-14.0591536,-14.4929886,-15.3779659,-16.5609722,-18.6198444,-19.4168167,-20.6577911,-22.2498741,-23.2070065,-25.1177,-25.8626747,-26.760458,-27.18132,-28.1788788,-28.9089127,-29.4013042,-30.171278,-30.5386124,-31.6012573,-32.45845,-33.7692223,-34.27179,-34.7768021,-35.1157875,-35.4678,-35.6366463,-35.9499855,-36.2913628,-37.16171,-37.5822029,-37.89954,-38.1013832,-39.22257,-39.5879135,-39.9574661,-40.76774,-41.15085,-41.96199,-42.6245,-43.0709343,-43.4662628,-43.8104858,-44.4019279,-44.7163734,-45.08624,-45.1773529,-45.2627373,-45.33187,-45.426,-45.411087,-45.1994553,-45.09395,-44.9436722,-44.9339828,-45.01875,-45.07291,-45.15622,-45.16679,-45.2414742,-45.3190575,-45.34564,-45.37258,-45.39964,-45.410923,-45.424263,-45.4579659,-45.4909,-45.50892,-45.5248947,-45.5939331,-45.6190262,-45.6298141,-45.63057,-45.6151962,-45.6033974,-45.48585,-45.0888176,-44.63188,-43.7953529,-42.15039,-41.8459244,-41.72025,-41.743412,-41.70977,-41.3850555,-40.18873,-38.53025,-37.58125,-37.0056725,-35.8118744,-35.0003548,-31.4033051,-28.843626,-27.4781475,-26.6268635,-26.0405731,-24.5687618,-21.2346783,-15.37584,-13.1824093,-12.4409771,-12.1958075,-12.0217047,-11.93545,-10.7440033,-7.002583,-6.53480053,-6.258085,-6.152751,-5.92245,-5.62029839,-4.980984,4.742104,4.67654753,4.914462,5.91950369,7.1455617,8.986796,9.402118,9.447103,9.954297,11.29599,12.3834143,15.94368,17.7371826,18.6790943,20.588768,22.0499477,24.8879147,26.1247253,26.4860382,26.54396,26.9095078,27.3886776,28.2528667,29.1681213,30.7694588,32.28257,35.23648,36.22008,37.42533,38.56734,39.5822945,40.16845,40.0900421,40.369,40.6965141,41.78094,43.33212,43.74716,44.8121529,45.53613,47.3867378,48.6779022,49.1761322,49.71334,51.31976,52.1605949,53.06982,53.70095,53.9341927,54.1993675,54.23332,54.0837746,53.89329,53.7693672,54.33628,54.50884,54.14238,53.5084572,53.26521,52.9936028,53.5548553,53.7871132,54.2586365,54.41176,54.10162,53.5533676,53.35999,53.49356,53.7850761,53.8911819,53.89349,53.98543,54.0325966,54.16937,54.2724571,53.7728729,53.45095,53.2353935,53.1842957,53.16105,53.3544731,53.4491234,53.9526672,54.1659927,54.2343941,54.1959839,54.1606865,54.16399,54.1018181,54.00508,53.9086266,53.76462,53.6772537,53.5589943,53.30074,52.95733,52.2567825,51.7381134,51.22956,50.5941925,50.34295,49.46271,48.9779,48.5297356,48.21814,47.9859543,48.0013237,47.9379578,47.72254,47.4008865,47.259758,46.6148643,45.5137634,45.3844452,45.5001945,45.68152,45.99042,46.56496,46.64969,45.89512,45.6384468,45.4342728,45.4000168,45.4405365,45.5778847,45.6555252,45.708683,45.7023659,45.6929741,45.7419548,45.7256966,45.63025,44.9286346,44.7265244,44.5767441,44.6639481,44.79259,44.7998543,44.4495277,44.18491,43.93806,43.992775,44.0295563,44.0498734,43.99412,43.7494164,43.7125549,43.712,43.7298927,43.764576,43.7104568,43.688427,43.5243034,43.43504,43.4113235,43.36798,42.4620819,41.5116348,38.5550041,32.7453232,26.56522,16.5706863,13.5753994,9.161587,8.412231,7.860225,5.770577,4.661192,2.60150719,1.88813341,-0.21306245,-4.00007534,-18.9709473,-27.926939,-33.0961838,-36.2485352,-37.3616676,-39.3066559,-41.2927322,-42.4957428,-43.1485367,-44.7249336,-44.943573,-45.10858,-45.354702,-45.3464,-45.35305,-45.37379,-45.3457451,-45.0847321,-45.0564651,-45.085743,-45.6649,-45.71014,-45.23604,-45.0352478,-44.91934,-44.78746,-44.70863,-44.5818329,-44.4020271,-44.319706,-44.2211571,-44.196804,-43.9232559,-43.38719,-43.04315,-42.7323875,-42.7737236,-42.80022,-42.70773,-42.5643272,-39.9633942,-39.16733,-38.4110222,-32.636898,-30.5087242,-27.6986427,-24.57287,-23.692625,-22.6465588,-21.9287262,-19.9291458,-18.2773781,-13.2286034,-9.577109,-8.603731,-6.89460754,-5.43534327,-4.54618263,-3.64346623,-2.59939981,-2.07951975,2.31469131,3.0380888,4.607767,5.32855225,5.906642,6.16173,6.384541,7.04001951,7.418836,8.405226,9.405544,12.6315432,13.7829895,15.2191763,16.7484417,19.9306,21.6506233,23.2104454,24.4977169,25.0346813,25.30676,26.2389545,26.88045,27.9044743,30.606863,32.0414429,33.7644157,35.1012039,36.4425659,37.05541,40.7815437,41.7778854,42.56987,43.67473,43.9453926,44.8893051,45.70131,46.74261,47.3306465,47.9995,49.2449722,50.44381,50.9435768,52.18824,52.9054832,53.1879959,54.37853,55.025753,55.60447,56.33797,56.87993,56.92584,57.021946,57.21785,57.60909,57.7637863,57.80884,57.8364563,57.543026,57.88548,58.2732544,58.2408333,58.0234146,57.99099,58.00393,57.9269028,57.80622,57.7055168,57.68892,57.6866035,57.6839523,57.7019844,57.66756,57.40279,57.21598,57.0038528,56.9468,56.8248749,56.4176331,56.2021141,55.7256775,55.66696,55.65511,55.5524635,55.4091835,55.1808434,55.1741676,54.6417923,53.9137077,50.4250336,46.7496643,44.57508,40.4311447,38.2679176,36.7718468,36.3227844,35.7413139,33.87974,30.8242,28.9099884,25.5967369,22.8496017,18.764246,15.1162844,11.8185005,9.575569,7.74628162,6.925604,6.53588057,6.509816,6.50939465,5.574537,5.574537,3.95567083,1.72430909,-1.79482353,-2.22861934,-3.71177626,-4.276542,-7.925582,-10.8458023,-11.9825859,-13.0956326,-16.0638714,-18.5778713,-19.4063759,-20.78773,-23.3895912,-25.8098488,-26.83725,-27.2258453,-27.2554035,-28.4685974,-32.2561646,-33.8057,-34.7632675,-35.4957352,-35.729847,-36.42817,-36.43206,-38.27517,-38.3336143,-42.535347,-42.58589,-43.1390152,-43.4636459,-44.23055,-44.7352066,-44.7929039,-44.7967224,-44.7019539,-44.6951,-44.76998,-44.8423653,-44.8882637,-44.91204,-44.85185,-44.8132935,-44.79464,-45.01487,-45.132534,-45.2049561,-45.2755051,-45.2822037,-45.15041,-45.0920334,-45.0590134,-45.01777,-44.97426,-44.90967,-44.6192932,-44.3313637,-44.0820045,-43.6566,-43.3860321,-43.19856,-43.0621567,-42.961216,-42.8787575,-42.7724724,-42.7145958,-42.63044,-42.4527931,-42.3390541,-42.0445747,-41.77196,-41.38646,-40.8212128,-40.7381363,-40.80259,-40.8765564,-40.9677048,-40.8538361,-39.8946266,-39.579895,-39.21836,-38.375782,-37.4173851,-36.58418,-36.0146446,-34.6000328,-32.69036,-27.8883934,-23.5332851,-19.1771145,-18.5252,-18.8279057,-19.1407032,-19.42601,-19.2380886,-17.4754219,-14.5466433,-11.1540089,-9.154355,-7.96925068,-7.52965355,-6.28890038,-4.86699438,-3.16297865,3.72210145,4.441311,4.90696144,5.15936041,5.347531,5.49871826,6.08589029,7.07972574,7.87043238,8.690545,9.394233,10.2527695,11.5210409,12.81786,14.0625963,14.9317923,15.4005775,16.7549725,18.11003,21.2225952,25.1258011,26.7395325,27.8655987,29.2665443,30.4367065,33.1381378,35.3804169,37.2119255,38.8833351,40.4359055,42.04165,43.5648,44.61499,44.9564476,45.118763,45.2838821,45.61523,45.7789154,45.8505135,45.8579826,46.3753853,47.1786346,48.7844276,51.0027161,52.0655823,52.794117,53.86925,53.7672119,53.04572,52.3985977,51.5328445,51.49959,51.7108727,52.64348,52.8731079,52.92332,52.6179924,52.39084,52.2505875,52.40903,52.62366,52.61957,52.5312271,52.239212,52.04797,51.53036,51.3371925,51.2323647,51.0282669,50.9754448,50.98367,51.00551,51.0235977,51.0416565,51.12907,51.45702,51.5334435]

# %%
timestamps = [0.0215901,0.0413592979,0.0598358,0.0779771,0.0961634,0.1162277,0.1319171,0.154446408,0.171133012,0.186476216,0.211572617,0.229720712,0.244751215,0.259531528,0.273851633,0.289424539,0.31157425,0.327592552,0.343249649,0.357129842,0.372194052,0.387104839,0.409552842,0.426291436,0.440841138,0.45472005,0.476228148,0.492018938,0.5058354,0.5272941,0.5420194,0.556872547,0.572352469,0.59617734,0.611389339,0.6278647,0.645188034,0.663503945,0.68373394,0.70423156,0.724568069,0.7494777,0.7695235,0.789892,0.8109184,0.829911,0.850531,0.8673315,0.8842716,0.900263131,0.917014241,0.935026944,0.9513385,0.967027,0.981550336,0.9957494,1.0118084,1.02847874,1.05433679,1.070875,1.0859586,1.10134149,1.11762154,1.13447249,1.14990091,1.16504431,1.18663871,1.20081174,1.21540427,1.23423779,1.25033271,1.26526,1.28053164,1.30704784,1.32345748,1.33939421,1.3559618,1.37118,1.38558137,1.40407622,1.42257953,1.44333589,1.46069622,1.480644,1.49826431,1.51636577,1.533972,1.55019653,1.56830347,1.58346069,1.59752309,1.62104166,1.634336,1.64915013,1.6710211,1.68524623,1.7008177,1.71584153,1.73093164,1.75207388,1.76589572,1.78801167,1.80070043,1.82125044,1.83470392,1.84909272,1.86968708,1.88210893,1.90358746,1.91700983,1.9385699,1.95293224,1.97119093,1.98364472,2.00371432,2.01774621,2.03139758,2.05112314,2.071551,2.08414626,2.09864831,2.12014437,2.13197041,2.1526556,2.16611218,2.186776,2.198704,2.223347,2.24172688,2.25723672,2.273312,2.29068065,2.30739212,2.32492542,2.34026146,2.35296226,2.37460184,2.39030814,2.40405321,2.42549014,2.44025135,2.45243454,2.47321939,2.48845148,2.50771618,2.52056623,2.53903627,2.55326056,2.57258487,2.58725762,2.60701346,2.62066126,2.63898134,2.65185475,2.67776752,2.692573,2.70690155,2.71980023,2.74607968,2.76082754,2.77623153,2.78856182,2.80955458,2.82249546,2.837269,2.85977864,2.87799454,2.89396453,2.908203,2.92387247,2.9367826,2.97740436,2.992075,3.00398374,3.0188787,3.03269625,3.04987383,3.07227182,3.09318924,3.11924553,3.13465047,3.149093,3.16375375,3.179992,3.19348979,3.21627116,3.22920775,3.25075364,3.264493,3.27781987,3.29996276,3.31395936,3.326797,3.34918284,3.36362314,3.384509,3.3977778,3.41678739,3.4307704,3.44938469,3.4678328,3.47986746,3.49325085,3.52250314,3.53526855,3.55181026,3.56261539,3.58306956,3.59602976,3.61465335,3.6343627,3.6455276,3.66505384,3.67779636,3.699687,3.71629333,3.72929239,3.7482717,3.7672112,3.77845669,3.79938149,3.8117063,3.83535337,3.84881186,3.863884,3.8810997,3.89648819,3.91117454,3.93464613,3.94806933,3.9626174,3.977304,4.000094,4.01425076,4.027677,4.050928,4.0663743,4.078805,4.100421,4.112762,4.13402271,4.147823,4.168148,4.181546,4.194434,4.21458769,4.234454,4.24627256,4.267389,4.279839,4.29972649,4.31163836,4.33085966,4.35168648,4.362972,4.38365,4.39633942,4.41744375,4.43002129,4.44764042,4.466908,4.47948742,4.499048,4.51545048,4.534908,4.54595041,4.565392,4.579016,4.59901428,4.61179161,4.63119745,4.650847,4.66193247,4.680286,4.693625,4.71575928,4.73079872,4.744929,4.769281,4.78702927,4.803739,4.819657,4.833666,4.84914541,4.863388,4.88043642,4.90398836,4.9196806,4.9343667,4.949221,4.96416235,4.97826433,5.00200224,5.015862,5.030509,5.053033,5.068207,5.08373356,5.10119247,5.11321354,5.13272,5.15332747,5.164783,5.184572,5.203093,5.21563673,5.235178,5.24725056,5.26773357,5.28068161,5.298999,5.317936,5.335206,5.346731,5.366881,5.385204,5.4033947,5.41543,5.435905,5.448127,5.4656167,5.478856,5.49898,5.51253271,5.536463,5.552247,5.567679,5.58252573,5.59752846,5.61950874,5.634312,5.649057,5.663705,5.67855549,5.70310354,5.71675825,5.72987127,5.751711,5.765573,5.78650856,5.80157852,5.815384,5.83816338,5.850684,5.86278534,5.88515425,5.897672,5.919816,5.93406,5.947398,5.965756,5.98546028,5.998189,6.016876,6.03605032,6.050361,6.064536,6.08580542,6.09968853,6.113552,6.135481,6.14788437,6.167163,6.18541431,6.196621,6.222381,6.23609734,6.253469,6.26443338,6.29050255,6.30400229,6.315398,6.335956,6.350873,6.3638587,6.379025,6.394981,6.420128,6.43492174,6.448346,6.464004,6.480597,6.50423241,6.519954,6.536378,6.54922247,6.57020664,6.58253336,6.60225439,6.616619,6.631618,6.64535,6.667518,6.68110466,6.70011,6.71345472,6.732529,6.74653149,6.76581955,6.787055,6.798616,6.819537,6.83212042,6.85392237,6.86483,6.88408375,6.896552,6.91574669,6.935861,6.947738,6.962433,6.98545933,6.999041,7.01880455,7.033563,7.04589128,7.068032,7.08190632,7.104278,7.11837244,7.132892,7.14760542,7.16198969,7.17980766,7.1979146,7.21551,7.23554468,7.251843,7.27847052,7.29612732,7.310851,7.32586861,7.340362,7.354045,7.37723255,7.397773,7.416463,7.43263674,7.44726324,7.461658,7.482286,7.49668932,7.509643,7.53322744,7.547443,7.560741,7.582207,7.59483,7.61448336,7.626922,7.6473856,7.66108751,7.68050528,7.699729,7.71060371,7.730751,7.74320173,7.764305,7.77655172,7.80376673,7.81475163,7.83370543,7.84549856,7.86440468,7.87679148,7.89710045,7.915694,7.928158,7.946884,7.96549654,7.97835255,8.000285,8.017679,8.032062,8.047815,8.063361,8.077509,8.099032,8.112595,8.135399,8.149843,8.165654,8.180526,8.194897,8.216182,8.229296,8.243962,8.264311,8.277119,8.300044,8.312346,8.331829,8.344509,8.380946,8.394113,8.405678,8.426146,8.437875,8.461682,8.4770155,8.490943,8.50575,8.518719,8.5447,8.56123352,8.573023,8.591632,8.604899,8.622336,8.636443,8.654298,8.674779,8.688396,8.706465,8.71952152,8.744354,8.757421,8.769024,8.796216,8.812389,8.827488,8.842365,8.856092,8.869043,8.889463,8.904667,8.926353,8.943383,8.957458,8.970956,8.990803,9.006292,9.020615,9.041232,9.057027,9.07029152,9.092745,9.109124,9.12278652,9.135818,9.16214752,9.17875,9.192209,9.206073,9.219424,9.239924,9.257768,9.275732,9.291307,9.305694,9.328908,9.344054,9.359478,9.375195,9.389677,9.40956,9.423969,9.444196,9.457177,9.477213,9.488678,9.504604,9.531735,9.546896,9.560414,9.575438,9.588582,9.610329,9.62406349,9.639139,9.661777,9.675264,9.689343,9.71065,9.723334,9.744088,9.755525,9.77643,9.789522,9.810437,9.823792,9.839299,9.86164951,9.876928,9.891064,9.90556,9.920463,9.947217,9.959742,9.972503,9.996053,10.0109968,10.0257454,10.0401058,10.0614023,10.0750332,10.0893335,10.1121693,10.12579,10.139925,10.1543713,10.1760731,10.1913176,10.2054119,10.2262125,10.24027,10.261095,10.27256,10.2908726,10.3109713,10.3254108,10.3450317,10.358202,10.378418,10.3914585,10.4112568,10.4240589,10.4375429,10.4585485,10.4737921,10.4939232,10.5081015,10.5284643,10.5401392,10.5611982,10.5751657,10.5896244,10.6049585,10.6309357,10.64365,10.6575985,10.6714048,10.6900387,10.7050133,10.7306271,10.7446194,10.7570705,10.7769508,10.7912779,10.8060331,10.8208208,10.8484716,10.8614349,10.8739672,10.8920679,10.9049845,10.9291248,10.9467182,10.9634552,10.9819517,10.9998274,11.0180416,11.0360756,11.0539331,11.0728951,11.0942154,11.1132088,11.1312714,11.148469,11.1662817,11.1839018,11.2015572,11.2180548,11.2366848,11.2541943,11.2714014,11.2878,11.3038864,11.3185539,11.33259,11.355422,11.3710861,11.3822746,11.4050283,11.41994,11.4348011,11.448719,11.4709377,11.4857483,11.5017776,11.5149584,11.5297375,11.5524006,11.5671329,11.5807753,11.59649,11.6214561,11.637619,11.6537848,11.6690941,11.6858034,11.7010422,11.7169514,11.731945,11.7468252,11.7728138,11.7903662,11.8063984,11.8223972,11.8376884,11.8504972,11.8671331,11.8820095,11.90395,11.9176989,11.9334764,11.9540348,11.9669724,11.986701,11.9992371,12.0194759,12.0322647,12.0514927,12.0662308,12.0855341,12.09872,12.1178513,12.138998,12.1519594,12.17141,12.1846514,12.2027817,12.2150993,12.2416964,12.2576437,12.2718105,12.2917528,12.3051224,12.32266,12.335187,12.35235,12.365695,12.3842468,12.40431,12.4223957,12.4346838,12.4516077,12.4646921,12.4915228,12.5084934,12.5225191,12.5361691,12.5560007,12.5713844,12.583087,12.60577,12.6228647,12.6392012,12.65394,12.6678591,12.6829166,12.6983871,12.7201214,12.7328882,12.7537355,12.7681637,12.7819309,12.8017979,12.8213978,12.8352127,12.8548546,12.8674183,12.8894339,12.9045887,12.9238338,12.936347,12.9534645,12.9658728,12.9863806,13.0054836,13.0194254,13.037466,13.05834,13.07289,13.0848093,13.1022205,13.1207571,13.1386528,13.1507378,13.1754,13.1918516,13.2052927,13.218832,13.2359037,13.2488232,13.2764511,13.2889862,13.3006649,13.3187132,13.33899,13.3517237,13.3709173,13.3857031,13.3999367,13.4228592,13.4377136,13.4575129,13.47214,13.4860125,13.5063353,13.5215206,13.5435524,13.5616951,13.5761929,13.5917835,13.6085033,13.623435,13.6365108,13.65803,13.6751013,13.6885567,13.7024393,13.72201,13.73704,13.753684,13.7938738,13.8092794,13.82241,13.8351164,13.8523026,13.8630819,13.881815,13.9018841,13.9127541,13.9324465,13.9506865,13.9632454,13.9822483,14.0014734,14.01355,14.0320616,14.0504761,14.0622272,14.0811586,14.0999022,14.1120729,14.1338749,14.1481371,14.1680679,14.1813021,14.199213,14.2182493,14.2329111,14.24556,14.26716,14.2820892,14.2973871,14.3121223,14.3350906,14.350317,14.3672781,14.3830471,14.398921,14.4154272,14.43126,14.4519243,14.4662237,14.4801331,14.5010023,14.5140076,14.53374,14.5471487,14.5609636,14.5839167,14.5973482,14.6118307,14.6332026,14.6460876,14.6661348,14.6790867,14.7013693,14.71482,14.7279758,14.7477179,14.76197,14.78239,14.80307,14.81459,14.8359394,14.8497953,14.8618183,14.88201,14.9008112,14.9142275,14.9344807,14.9466352,14.9659977,14.9797564,14.9997158,15.0120935,15.0322,15.0509806,15.0650215,15.0876331,15.0997152,15.1128378,15.1272879,15.1506681,15.16626,15.18069,15.19455,15.21816,15.2329311,15.2471371,15.2617,15.2775965,15.2938089,15.3173923,15.3317356,15.3453979,15.3669834,15.3804016,15.3947277,15.4194632,15.43364,15.4474649,15.467042,15.4796028,15.4941158,15.5142708,15.5333271,15.55399,15.5656223,15.586545,15.5985136,15.6164427,15.6299143,15.6502552,15.6636553,15.6840763,15.69634,15.7181158,15.7323818,15.7472105,15.767993,15.7809534,15.8024187,15.8164835,15.8291531,15.8489933,15.8624325,15.8832483,15.89545,15.9160767,15.92854,15.9481077,15.9625406,15.9792433,16.001545,16.0149632,16.02849,16.05182,16.0689163,16.0836525,16.098423,16.11174,16.1275921,16.1454353,16.16444,16.18127,16.1981564,16.2155113,16.23983,16.2556381,16.271452,16.2893925,16.30505,16.32576,16.339426,16.3524952,16.3711376,16.3854847,16.4060116,16.4198322,16.4369831,16.4583778,16.4733086,16.4875336,16.5069218,16.5193081,16.5360527,16.5560322,16.5702972,16.5895119,16.6028957,16.6265011,16.6395626,16.6509266,16.6755886,16.6884174,16.7061024,16.7206,16.7378025,16.7501488,16.7710667,16.794426,16.8142624,16.8301582,16.8453083,16.86086,16.8763924,16.8910637,16.9041119,16.9252281,16.9408379,16.953577,16.9770355,16.9918289,17.0036068,17.0227871,17.0380287,17.05827,17.0726833,17.0869789,17.1081161,17.1213646,17.14588,17.1603527,17.17197,17.1928368,17.2043324,17.221777,17.2426414,17.2552814,17.2746372,17.28683,17.3119011,17.32584,17.3381824,17.3579121,17.3728466,17.3929977,17.4057026,17.4190159,17.4443436,17.45844,17.4706821,17.4948368,17.5078487,17.5207539,17.53968,17.5551434,17.5734673,17.58785,17.606123,17.62026,17.6381149,17.6577911,17.6705914,17.6890068,17.7092972,17.7212029,17.7386723,17.7609615,17.77275,17.7930489,17.805706,17.8260288,17.83971,17.863636,17.8805275,17.8973064,17.9114,17.9247971,17.94048,17.9549541,17.9773254,17.9951973,18.0083447,18.0224361,18.0457821,18.0584545,18.0729523,18.0940514,18.10738,18.1213665,18.1410789,18.1565628,18.170578,18.1915245,18.2063,18.2295666,18.2436352,18.2570286,18.2706661,18.2981415,18.3113327,18.3231163,18.3439426,18.35724,18.3769989,18.39006,18.4116459,18.4238358,18.4436054,18.464407,18.4813156,18.4925232,18.5128555,18.5253468,18.5381126,18.5658588,18.5814018,18.595541,18.6080341,18.629385,18.6420078,18.656065,18.679987,18.6950283,18.7087765,18.72241,18.7470131,18.788023,18.8121185,18.8350811,18.8558636,18.882061,18.9033165,18.9220467,18.9434,18.9625149,18.9850426,19.0053043,19.02114,19.03166,19.0456886,19.0679951,19.0826187,19.0964565,19.1182346,19.1311646,19.1457844,19.1674747,19.1818447,19.2036247,19.2151165,19.2340527,19.253582,19.26724,19.28645,19.2982941,19.3183689,19.3297043,19.35454,19.36862,19.3811989,19.40166,19.41499,19.4366989,19.4501572,19.4636974,19.4832439,19.5019836,19.5156727,19.535574,19.5497932,19.56345,19.5782719,19.5988216,19.6140327,19.6323147,19.650835,19.6733246,19.6977177,19.71987,19.7406368,19.76526,19.7851563,19.8081379,19.8322773,19.85163,19.8728867,19.89438,19.914608,19.9341087,19.9527988,19.9731274,19.9947433,20.0132732,20.0336018,20.0523758,20.0701485,20.0889168,20.109663,20.1267452,20.1440353,20.1639023,20.1827412,20.20067,20.22017,20.238903,20.2585144,20.28058,20.3018,20.3267345,20.3530655,20.3764057,20.4006329,20.4218674,20.4447021,20.46573,20.4846172,20.5035534,20.5203876,20.5384712,20.5552349,20.5754681,20.5944214,20.6123924,20.6285267,20.6489334,20.6674652,20.68586,20.7061729,20.7259941,20.7431,20.7613125,20.77743,20.8027687,20.8195133,20.8355179,20.851902,20.8658066,20.8779812,20.89797,20.9148674,20.9278526,20.9508781,20.9642925,20.9788742,21.0021858,21.0177212,21.0312729,21.0513458,21.0644531,21.0782814,21.0983772,21.1114388,21.132309,21.1446419,21.1610813,21.1852627,21.20215,21.2191887,21.2355347,21.2527447,21.2705173,21.2886753,21.31013,21.3298912,21.3476276,21.364233,21.3800468,21.3966465,21.41216,21.4284477,21.44626,21.4636669,21.4805927,21.4968281,21.5133343,21.5300159,21.5482635,21.5658436,21.5818615,21.596056,21.61281,21.6294422,21.6527615,21.6673031,21.68192,21.695816,21.718317,21.7333775,21.748806,21.7636528,21.7783279,21.8014221,21.8155422,21.8290329,21.846117,21.8634567,21.8814621,21.8976116,21.9138622,21.9305382,21.9475155,21.96666,21.9844112,22.0007515,22.0273838,22.0432758,22.0589,22.0782337,22.0953445,22.109602,22.1248131,22.13921,22.1618958,22.1767635,22.1907558,22.2064133,22.2220879,22.2397137,22.2560425,22.2826138,22.2972088,22.31232,22.3260536,22.3410187,22.3652115,22.38216,22.3954449,22.4096413,22.4254055,22.4400654,22.4557686,22.4722786,22.4894028,22.5119362,22.52628,22.5477772,22.5589447,22.5797367,22.5929413,22.6063137,22.6336632,22.6453266,22.6571655,22.6769657,22.69023,22.71052,22.7313862,22.7493954,22.7649574,22.7812347,22.79795,22.8127689,22.8287,22.843895,22.85932,22.8845215,22.8994865,22.9146671,22.9309788,22.945591,22.9608231,22.974659,22.9981728,23.0131931]

# %%
plt.plot(timestamps, angles)
plt.title('Raw Angles - Simulated Jittery Movement')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
min_angles = [-44.27099,-44.0424843,-45.63057,-45.71014,-45.2822037]
min_tstmps = [4.565392,9.375195,13.218832,17.1213646,20.77743]
max_angles = [53.919838,53.98442,54.50884,58.2732544]
max_tstmps = [6.76581955,10.9819517,14.81459,18.8350811]

# %%
plt.plot(timestamps, angles)
plt.plot(min_tstmps, min_angles, 'go')

plt.plot(max_tstmps, max_angles, 'ro')
plt.legend(['angles', 'min angles', 'max angles'])
plt.title('Max and Min Angles Achieved')
# Out:
# Text(0.5, 1.0, 'Max and Min Angles Achieved')

# %%
import matplotlib.pyplot as plt

ang_vel = calculate_angular_velocities(angles, timestamps)
fig, ax1 = plt.subplots()

# Plot the smoothed angles on the left-hand side y-axis
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Unsmoothed Angles (deg)', color='tab:blue')
ax1.plot(timestamps, angles, color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for the angular velocity
ax2 = ax1.twinx()
ax2.set_ylabel('Angular Velocity (deg/s)', color='tab:orange')  
ax2.plot(timestamps[0:-1], ang_vel, color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title('Angular Velocities (UnSmoothed Angles)')
plt.show()

# %%
# Pad and Calculate fourier coeffs + angles
ang_vel_padded = np.pad(ang_vel, (0, int(2**(np.ceil(math.log(len(ang_vel),2))+4)-len(ang_vel))))

fourier_coeffs = np.fft.fft(ang_vel_padded)
fourier_mag = np.abs(fourier_coeffs)
N = len(fourier_mag)

fourier_mag_adj = fourier_mag / fourier_mag[0]

# Restrict to range we care about
sampling_rate = 1/60
freqs = np.fft.fftfreq(N, sampling_rate)

freqs_restricted = freqs[:N//2]

# Get the restricted frequency range
for i in range(len(freqs_restricted)):
    if freqs_restricted[i] > 7:
        freqs_restricted = freqs_restricted[:i]
        fourier_mag_restricted = fourier_mag_adj[:i]
        break

plt.plot(freqs_restricted[:N//2], fourier_mag_restricted[:N//2])  # Plotting only the positive frequencies
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Fourier Magnitude Spectrum")
plt.show()

# %%
# Default smoothness measure
smoothness_measure = 0

for i in range(len(freqs_restricted)-1):
    smoothness_measure -= math.sqrt( (1 / (len(freqs_restricted) - 1)) ** 2 + (fourier_mag_restricted[i+1] - fourier_mag_restricted[i]) ** 2 )

smoothness_measure
# Out:
# -138.76886224028436

# %%
smoothed_angles = moving_average_angles(angles, 4)
plt.plot(timestamps[1:-2], smoothed_angles)
plt.title('Smoothed Angles')
plt.xlabel('Time (s)')
plt.ylabel('Angle (deg)')
# Out:
# Text(0, 0.5, 'Angle (deg)')

# %%
ang_vel = calculate_angular_velocities(smoothed_angles, timestamps[1:-2])

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots()

# Plot the smoothed angles on the left-hand side y-axis
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Smoothed Angles (deg)', color='tab:blue')
ax1.plot(timestamps[1:-3], smoothed_angles[0:-1], color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis for the angular velocity
ax2 = ax1.twinx()
ax2.set_ylabel('Angular Velocity (deg/s)', color='tab:orange')  
ax2.plot(timestamps[1:-3], ang_vel, color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title('Angular Velocities (Smoothed Angles)')
plt.show()

# %%
# Pad and Calculate fourier coeffs + angles
ang_vel_padded = np.pad(ang_vel, (0, int(2**(np.ceil(math.log(len(ang_vel),2))+4)-len(ang_vel))))

fourier_coeffs = np.fft.fft(ang_vel_padded)
fourier_mag = np.abs(fourier_coeffs)
N = len(fourier_mag)

fourier_mag_adj = fourier_mag / fourier_mag[0]

# Restrict to range we care about
sampling_rate = 1/60
freqs = np.fft.fftfreq(N, sampling_rate)

freqs_restricted = freqs[:N//2]

# Get the restricted frequency range
for i in range(len(freqs_restricted)):
    if freqs_restricted[i] > 7:
        freqs_restricted_nonsmooth = freqs_restricted[:i]
        fourier_mag_restricted_nonsmooth = fourier_mag_adj[:i]
        break

plt.plot(freqs_restricted_nonsmooth[:N//2], fourier_mag_restricted_nonsmooth[:N//2])  # Plotting only the positive frequencies
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Fourier Magnitude Spectrum, non-smoothed angles")
plt.show()

# %%
# Default smoothness measure
smoothness_measure = 0

for i in range(len(freqs_restricted_nonsmooth)-1):
    smoothness_measure -= math.sqrt( (1 / (len(freqs_restricted_nonsmooth) - 1)) ** 2 + (fourier_mag_restricted_nonsmooth[i+1] - fourier_mag_restricted_nonsmooth[i]) ** 2 )

smoothness_measure
# Out:
# -120.27777465865138

# %%
plt.plot(freqs_restricted_smooth[:N//2], fourier_mag_restricted_smooth[:N//2])  # Plotting only the positive frequencies
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Fourier Magnitude Spectrum, smoothed angles")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create 1x2 subplots with shared y-axis
fig, axarr = plt.subplots(1, 2, sharey=True, figsize=(10, 5))

# Plot data on the first axis
axarr[0].plot(freqs_restricted_smooth, fourier_mag_restricted_smooth)
axarr[0].set_title('Smooth Motion Fourier Magnitude\n(Spectral Arc-Length = -99.01)')
axarr[0].set_xlabel('Frequency (Hz)')
axarr[0].set_ylabel('Magnitude')

# Plot data on the second axis
axarr[1].plot(freqs_restricted_nonsmooth, fourier_mag_restricted_nonsmooth)
axarr[1].set_title('Simulated Tremor Motion Fourier Magnitude\n(Spectral Arc-Length = -120.28)')
axarr[1].set_xlabel('Frequency (Hz)')

# Display the plots
plt.tight_layout()
plt.subplots_adjust(top=0.85)  # Adjust the top padding to accommodate the main title
plt.show()
